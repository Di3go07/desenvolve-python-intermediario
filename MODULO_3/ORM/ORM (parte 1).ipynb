# %% [markdown]
# > Projeto Desenvolve <br>
# Programação Intermediária com Python <br>
# Profa. Camila Laranjeira (mila@projetodesenvolve.com.br) <br>
#
# # 3.14 - ORM

# %% [markdown]
# ## Exercícios
#
# #### Q1. Conhecendo os dados
# Baixe o seguinte csv onde iremos trabalhar. Ele contém informações sobre salários de profissionais de dados de uma empresa hipotética entre 2009 e 2016
# * https://github.com/camilalaranjeira/python-intermediario/blob/main/salaries.csv
#
# Suas colunas, descritas na [página do Kaggle que contém o dataset](https://www.kaggle.com/datasets/krishujeniya/salary-prediction-of-data-professions?resource=download), são:
# * FIRST NAME: Primeiro nome do profissional de dados (String)
# * LAST NAME: Sobrenome do profissional de dados (String)
# * SEX: Gênero do profissional de dados (String: 'F' para Feminino, 'M' para Masculino)
# * DOJ (Date of Joining): A data em que o profissional de dados ingressou na empresa (Data no formato MM/DD/AAAA)
# * CURRENT DATE: A data atual ou a data de referência dos dados (Data no formato MM/DD/AAAA)
# * DESIGNATION: O cargo ou designação do profissional de dados (String: ex., Analista, Analista Sênior, Gerente)
# * AGE: Idade do profissional de dados (Integer)
# * SALARY: Salário anual do profissional de dados (Float)
# * UNIT: Unidade de negócios ou departamento em que o profissional de dados trabalha (String: ex., TI, Finanças, Marketing)
# * LEAVES USED: Número de licenças utilizadas pelo profissional de dados (Integer)
# * LEAVES REMAINING: Número de licenças restantes para o profissional de dados (Integer)
# * RATINGS: Avaliações de desempenho do profissional de dados (Float)
# * PAST EXP: Experiência de trabalho anterior em anos antes de ingressar na empresa atual (Float)
#
# Na célula a seguir, **carregue os dados do CSV e dê uma olhada neles antes de seguir**.

# %%
###imports 
import pandas as pd
from typing import List
from typing import Optional
from sqlalchemy import create_engine, URL
from sqlalchemy import text, select
from sqlalchemy import ForeignKey, String, Enum
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, relationship
from sqlalchemy.orm import sessionmaker
from enum import Enum
from datetime import date

# %%
###importando o banco
df = pd.read_csv('Salary_Prediction_Data_Professions.csv')
display(df)
# Out:
#      FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION  \
# 0        TOMASA       ARMEN   F   5-18-2014   01-07-2016         Analyst
# 1         ANNIE         NaN   F         NaN   01-07-2016       Associate
# 2         OLIVE        ANCY   F   7-28-2014   01-07-2016         Analyst
# 3        CHERRY     AQUILAR   F  04-03-2013   01-07-2016         Analyst
# 4          LEON  ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst
# ...         ...         ...  ..         ...          ...             ...
# 2634  KATHERINE      ALSDON   F   6-28-2011   01-07-2016  Senior Manager
# 2635     LOUISE     ALTARAS   F   1-14-2014   01-07-2016         Analyst
# 2636      RENEE      ALVINO   F   1-23-2014   01-07-2016         Analyst
# 2637       TERI   ANASTASIO   F   3-17-2014   01-07-2016         Analyst
# 2638    GREGORY      ABARCA   M   9-18-2014   01-07-2016         Analyst
#
#        AGE  SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  \
# 0     21.0   44570     Finance         24.0               6.0      2.0
# 1      NaN   89207         Web          NaN              13.0      NaN
# 2     21.0   40955     Finance         23.0               7.0      3.0
# 3     22.0   45550          IT         22.0               8.0      3.0
# 4      NaN   43161  Operations         27.0               3.0      NaN
# ...    ...     ...         ...          ...               ...      ...
# 2634  36.0  185977  Management         15.0              15.0      5.0
# 2635  23.0   45758          IT         17.0              13.0      2.0
# 2636  21.0   47315         Web         29.0               1.0      5.0
# 2637  24.0   45172         Web         23.0               7.0      3.0
# 2638  24.0   49176   Marketing         17.0              13.0      2.0
#
#       PAST EXP
# 0            0
# 1            7
# 2            0
# 3            0
# 4            3
# ...        ...
# 2634        10
# 2635         0
# 2636         0
# 2637         1
# 2638         2
#
# [2639 rows x 13 columns]

# %% [markdown]
# #### Q2. Modelando os dados
# Você deve **criar um ORM com SQLAlchemy capaz de comportar os dados dessa base**.
#
# * Crie um campo de chave primária `ID`, que deve ser incrementado automaticamente
# * Os campos SEX, DESIGNATION e UNIT devem ser definidos como classes `Enum` com os possíveis valores (consulte os valores únicos dessas colunas)
# * Para os outros campos, consulte os tipos de dados informados na descrição acima

# %%
### buscando valores únicos de colunas específicas
lista_SEX = []

SEX_values = df["SEX"].drop_duplicates()
for value in SEX_values:
    lista_SEX.append(value)
    

lista_DESIGNATION = []

DESIGNATION_values = df["DESIGNATION"].drop_duplicates()
for value in DESIGNATION_values:
    lista_DESIGNATION.append(value)

lista_UNIT = []

UNIT_values = df["UNIT"].drop_duplicates()
for value in UNIT_values:
    lista_UNIT.append(value)
    
print(lista_SEX)
print(lista_DESIGNATION)
print(lista_UNIT)
# Out:
# ['F', 'M']
# ['Analyst', 'Associate', 'Senior Analyst', 'Senior Manager', 'Manager', 'Director']
# ['Finance', 'Web', 'IT', 'Operations', 'Marketing', 'Management']

# %%
### buscando colunas com valores NaN no banco
colunas_com_nan = df.columns[df.isna().any()].tolist()

print("Colunas com valores NaN:", colunas_com_nan)
#assim, altera o campo nullable da classe para não ter erro ao importar os dados para a tabela
# Out:
# Colunas com valores NaN: ['LAST NAME', 'DOJ', 'AGE', 'LEAVES USED', 'LEAVES REMAINING', 'RATINGS']

# %%
### criando as classes Enum
class Sex(Enum):
    M = 'M'
    F = 'F'
    
class Designation(Enum):
    Analyst = 'Analyst'
    Associate = 'Associate'
    Senior_Analyst = 'Senior Analyst'
    Manager = 'Manager'
    Senior_Manager = 'Senior Manager'
    Director = 'Director'
    
class Unit(Enum):
    Finance = 'Finance'
    Web = 'Web'
    IT = 'IT'
    Operations = 'Operations'
    Marketing = 'Marketing'
    Management = 'Management'

# %%
### criando o ORM
class Base(DeclarativeBase):
    pass

class Funcionarios(Base):
    __tablename__ = 'employees'
    
    id: Mapped[int] = mapped_column(primary_key=True)
    first_name: Mapped[str] = mapped_column(nullable=True)
    last_name: Mapped[str] = mapped_column(nullable=False)
    sex: Mapped[Sex] = mapped_column(nullable=False)
    doj: Mapped[date] = mapped_column(nullable=True) 
    current_date: Mapped[date] = mapped_column(nullable=False)
    designation: Mapped[Designation] = mapped_column(nullable=False)
    age: Mapped[int] = mapped_column(nullable=True)
    salary: Mapped[float] = mapped_column( nullable=False)
    unit: Mapped[Unit] = mapped_column(nullable=False)
    leaves_used: Mapped[int] = mapped_column(default=0, nullable=True)
    leaves_remaining: Mapped[int] = mapped_column(default=0, nullable=True)
    ratings: Mapped[float] = mapped_column(default=0.0, nullable=True)
    past_experience: Mapped[float] = mapped_column(default=0.0, nullable=False)

# %% [markdown]
# #### Q3. Estabelecendo uma conexão
#
# Usando o método `create_engine` do SQLAlchemy, crie uma conexão com um novo banco de dados SQLite chamado `salarios`.

# %%
### entrando em contato
engine = create_engine('sqlite:///salarios.db', echo=True)

# %% [markdown]
# #### Q4. Criando as tabelas
# Crie as tabelas da questão Q2 no banco `salarios`.

# %%
###  criando a tabela
Base.metadata.create_all(engine)
# Out:
# 2025-01-16 15:47:20,911 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-16 15:47:20,913 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("employees")
# 2025-01-16 15:47:20,914 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-16 15:47:20,916 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# #### Q5. Populando
#
# Usando o método `to_sql` da biblioteca Pandas (veja [a documentação](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html)), popule o banco `salarios` com os dados do csv que você carregou na questão Q1.
# * Lembre-se de definir o parâmetro `if_exists='append'` para que as tabelas não sejam dropadas e recriadas.

# %%
### populando o banco salarios
df.to_sql('funcionarios', engine, if_exists='append', index=False)
# Out:
# 2025-01-16 16:04:17,178 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-16 16:04:17,188 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("funcionarios")
# 2025-01-16 16:04:17,189 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-16 16:04:17,211 INFO sqlalchemy.engine.Engine INSERT INTO funcionarios ("FIRST NAME", "LAST NAME", "SEX", "DOJ", "CURRENT DATE", "DESIGNATION", "AGE", "SALARY", "UNIT", "LEAVES USED", "LEAVES REMAINING", "RATINGS", "PAST EXP") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2025-01-16 16:04:17,212 INFO sqlalchemy.engine.Engine [generated in 0.01223s] [('TOMASA', 'ARMEN', 'F', '5-18-2014', '01-07-2016', 'Analyst', 21.0, 44570, 'Finance', 24.0, 6.0, 2.0, 0), ('ANNIE', None, 'F', None, '01-07-2016', 'Associate', None, 89207, 'Web', None, 13.0, None, 7), ('OLIVE', 'ANCY', 'F', '7-28-2014', '01-07-2016', 'Analyst', 21.0, 40955, 'Finance', 23.0, 7.0, 3.0, 0), ('CHERRY', 'AQUILAR', 'F', '04-03-2013', '01-07-2016', 'Analyst', 22.0, 45550, 'IT', 22.0, 8.0, 3.0, 0), ('LEON', 'ABOULAHOUD', 'M', '11-20-2014', '01-07-2016', 'Analyst', None, 43161, 'Operations', 27.0, 3.0, None, 3), ('VICTORIA', None, 'F', '2-19-2013', '01-07-2016', 'Analyst', 22.0, 48736, 'Marketing', 20.0, 10.0, 4.0, 0), ('ELLIOT', 'AGULAR', 'M', '09-02-2013', '01-07-2016', 'Analyst', 22.0, 40339, 'Marketing', 19.0, 11.0, 5.0, 0), ('JACQUES', 'AKMAL', 'M', '12-05-2013', '01-07-2016', 'Analyst', None, 40058, 'Marketing', 29.0, 1.0, 2.0, 2)  ... displaying 10 of 2639 total bound parameter sets ...  ('TERI', 'ANASTASIO', 'F', '3-17-2014', '01-07-2016', 'Analyst', 24.0, 45172, 'Web', 23.0, 7.0, 3.0, 1), ('GREGORY', 'ABARCA', 'M', '9-18-2014', '01-07-2016', 'Analyst', 24.0, 49176, 'Marketing', 17.0, 13.0, 2.0, 2)]
# 2025-01-16 16:04:17,217 INFO sqlalchemy.engine.Engine COMMIT
# 2639

# %% [markdown]
# #### Q6. Consultas SQL vs ORM
#
# Agrupe os dados por DESIGNATION e selecione o mínimo, máximo e a média dos salários (SALARY) divididos por 12. Já que o atributo SALARY é anual, dividir por 12 nos mostrará os valores mensais.
#
# Assumindo que a variável que armazena a sua conexão se chama `engine`, você deve realizar a query acima de três formas:
# * Executando a query SQL através de uma instância de conexão retornada pelo método `engine.connect()`
# * Executando a query SQL com o método `read_sql_query` do Pandas (veja [a documentação](https://pandas.pydata.org/docs/reference/api/pandas.read_sql_query.html)). Você usará mesma instância `engine.connect()` como um dos parâmetros.
# * Executando uma query criada com o módulo `select` do SQLAlchemy. Sua execução deve ser feita através de um objeto `Session` do módulo `orm` do SQLAlchemy (`Session(engine)`).

# %%
### query SQL com engine.connect
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM funcionarios")).fetchall()
                                                
    for row in result:
        print(row)
# Out:
# 2025-01-16 16:11:00,961 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-16 16:11:00,963 INFO sqlalchemy.engine.Engine SELECT * FROM funcionarios
# 2025-01-16 16:11:00,966 INFO sqlalchemy.engine.Engine [cached since 1164s ago] ()
# ('TOMASA', 'ARMEN', 'F', '5-18-2014', '01-07-2016', 'Analyst', 21.0, 44570, 'Finance', 24.0, 6.0, 2.0, 0)
# ('ANNIE', None, 'F', None, '01-07-2016', 'Associate', None, 89207, 'Web', None, 13.0, None, 7)
# ('OLIVE', 'ANCY', 'F', '7-28-2014', '01-07-2016', 'Analyst', 21.0, 40955, 'Finance', 23.0, 7.0, 3.0, 0)
# ('CHERRY', 'AQUILAR', 'F', '04-03-2013', '01-07-2016', 'Analyst', 22.0, 45550, 'IT', 22.0, 8.0, 3.0, 0)
# ('LEON', 'ABOULAHOUD', 'M', '11-20-2014', '01-07-2016', 'Analyst', None, 43161, 'Operations', 27.0, 3.0, None, 3)
# ('VICTORIA', None, 'F', '2-19-2013', '01-07-2016', 'Analyst', 22.0, 48736, 'Marketing', 20.0, 10.0, 4.0, 0)
# ('ELLIOT', 'AGULAR', 'M', '09-02-2013', '01-07-2016', 'Analyst', 22.0, 40339, 'Marketing', 19.0, 11.0, 5.0, 0)
# ('JACQUES', 'AKMAL', 'M', '12-05-2013', '01-07-2016', 'Analyst', None, 40058, 'Marketing', 29.0, 1.0, 2.0, 2)
# ('KATHY', 'ALSOP', 'F', '6-29-2014', '01-07-2016', 'Senior Analyst', 28.0, 63478, 'Operations', 20.0, 10.0, 3.0, 1)
# ('LILIAN', 'APELA', 'F', '11-11-2014', '01-07-2016', 'Analyst', 22.0, 43110, 'Finance', 15.0, 15.0, 3.0, 0)
# ('BELLE', 'ARDS', 'F', '03-10-2014', '01-07-2016', 'Analyst', 24.0, 41590, 'Marketing', 22.0, 8.0, 4.0, 1)
# ('VIRGIL', 'ACKIES', 'M', '02-01-2010', '01-07-2016', 'Senior Manager', 36.0, 160613, 'Finance', None, 11.0, 2.0, 9)
# ('WELDON', 'AIVAO', 'M', '08-01-2013', '01-07-2016', 'Analyst', 24.0, 44828, 'Finance', 15.0, 15.0, 5.0, 1)
# ('BOYD', 'AFTON', 'M', '3-22-2013', '01-07-2016', 'Analyst', 21.0, 45830, 'Web', 23.0, 7.0, 2.0, 0)
# ('BART', 'AGUILLERA', 'M', '7-27-2013', '01-07-2016', 'Analyst', 24.0, 43457, 'Management', 30.0, 0.0, 4.0, 1)
# ('CORINNE', 'ANDRZEJCZYK', 'F', '8-13-2014', '01-07-2016', 'Analyst', 21.0, 44812, 'IT', 16.0, None, 5.0, 0)
# ('ALONZO', 'ADSIDE', 'M', '9-16-2013', '01-07-2016', 'Analyst', 25.0, 47636, 'Finance', 27.0, 3.0, 3.0, 2)
# ('ROYCE', 'AGOSTO', 'M', '06-07-2014', '01-07-2016', 'Analyst', 24.0, 48651, 'Web', 27.0, 3.0, 5.0, 1)
# ('BURTON', 'AGUILER', 'M', '02-03-2013', '01-07-2016', 'Analyst', 23.0, 40411, 'Management', 21.0, 9.0, 3.0, 0)
# ('PHILLIP', 'ABDULA', 'M', '07-03-2013', '01-07-2016', 'Analyst', 24.0, 44665, 'Web', None, 12.0, 5.0, 0)
# ('ORVILLE', 'ADNEY', 'M', '6-23-2013', '01-07-2016', 'Analyst', 25.0, 46941, 'Marketing', 23.0, 7.0, 3.0, 1)
# ('KORY', 'ALEGRIA', 'M', '10-11-2013', '01-07-2016', 'Analyst', 22.0, 47734, 'Marketing', 28.0, 2.0, 5.0, 0)
# ('NETTIE', 'ANDRADA', 'F', '07-11-2014', '01-07-2016', 'Analyst', 23.0, 40541, 'Operations', 15.0, 15.0, 5.0, 1)
# ('WENDI', 'APPERT', 'F', '12-02-2013', '01-07-2016', 'Analyst', 25.0, 43920, 'Web', 28.0, None, 2.0, 2)
# ('BRENT', 'ABRIL', 'M', '02-11-2013', '01-07-2016', 'Analyst', 21.0, 45832, 'Management', 28.0, 2.0, 2.0, 0)
# ('HARRIETTE', 'ARMSTRONG', 'F', '1-22-2014', '01-07-2016', 'Analyst', 23.0, 48102, 'Marketing', 17.0, 13.0, 2.0, 0)
# ('GARLAND', 'AGLER', 'M', '09-07-2014', '01-07-2016', 'Analyst', 21.0, 48662, 'Management', 30.0, 0.0, 5.0, 0)
# ('OSWALDO', 'ALLENBAUGH', 'M', '2-15-2013', '01-07-2016', 'Analyst', 25.0, 49685, 'Operations', 15.0, 15.0, 2.0, 1)
# ('SEYMOUR', 'ALBEN', 'M', '12-21-2014', '01-07-2016', 'Senior Analyst', 25.0, 57488, 'Operations', 25.0, 5.0, 3.0, 0)
# ('ROXANNE', 'AMRINE', 'F', '3-13-2013', '01-07-2016', 'Analyst', 21.0, 45410, 'Marketing', 29.0, 1.0, 2.0, 0)
# ('CLAUD', 'ALLATEEF', 'M', '05-07-2013', '01-07-2016', 'Analyst', 21.0, 43030, 'Management', 22.0, 8.0, 5.0, 0)
# ('MARIANNA', 'ARGENTIERI', 'F', '11-07-2014', '01-07-2016', 'Analyst', 22.0, 42388, 'Management', 30.0, 0.0, 5.0, 0)
# ('FOSTER', 'ALDERMAN', 'M', '5-22-2014', '01-07-2016', 'Senior Analyst', 26.0, 68295, 'Operations', 28.0, 2.0, 5.0, 3)
# ('MAUDIE', 'ARENIVAR', 'F', '08-06-2011', '01-07-2016', 'Associate', 29.0, 73397, 'Web', 30.0, 0.0, 5.0, 2)
# ('TORI', 'ARCE', 'F', '12-16-2013', '01-07-2016', 'Analyst', 22.0, 47008, 'Management', 27.0, 3.0, 2.0, 0)
# ('KELLEY', 'ALLAM', 'M', '7-30-2014', '01-07-2016', 'Analyst', 23.0, 49898, 'Marketing', 19.0, 11.0, 5.0, 1)
# ('HILLARY', 'ANTONIA', 'F', '12-17-2014', '01-07-2016', 'Analyst', 23.0, 45389, 'Management', 27.0, 3.0, 2.0, 1)
# ('MICKEY', 'AGRAMONTE', 'M', '3-25-2013', '01-07-2016', 'Analyst', 22.0, 49326, 'Web', 29.0, 1.0, 3.0, 0)
# ('ROSIE', 'AMILL', 'F', '2-18-2013', '01-07-2016', 'Analyst', 24.0, 49901, 'Web', 24.0, 6.0, 4.0, 0)
# ('GAVIN', 'AINI', 'M', '11-18-2014', '01-07-2016', 'Analyst', 24.0, 42529, 'IT', 23.0, 7.0, 2.0, 2)
# ('ANNABELLE', 'ANTROBUS', 'F', '3-23-2014', '01-07-2016', 'Analyst', 25.0, 44448, 'Finance', 25.0, 5.0, 5.0, 2)
# ('CHRISTINE', 'ALPHONSE', 'F', '8-26-2011', '01-07-2016', 'Senior Manager', 39.0, 175497, 'Marketing', 30.0, 0.0, 4.0, 13)
# ('MELODIE', 'ARMENT', 'F', '07-01-2014', '01-07-2016', 'Analyst', 25.0, 47739, 'IT', 21.0, 9.0, 4.0, 2)
# ('MICHELL', 'ARCH', 'F', '1-31-2014', '01-07-2016', 'Analyst', 25.0, 49046, 'Web', 25.0, 5.0, 4.0, 2)
# ('ANDREW', 'ABALOZ', 'M', '3-31-2014', '01-07-2016', 'Analyst', 25.0, 47961, 'Operations', 20.0, 10.0, 3.0, 2)
# ('LUCRETIA', 'ARGYLE', 'F', '4-26-2014', '01-07-2016', 'Associate', 29.0, 96378, 'Operations', 23.0, 7.0, 2.0, 5)
# ('JODY', 'ADOLFO', 'M', '01-07-2015', '01-07-2016', 'Associate', 32.0, 76411, 'IT', 16.0, 14.0, 4.0, 9)
# ('GILDA', 'ARANCIBIA', 'F', '5-22-2013', '01-07-2016', 'Analyst', 23.0, 40264, 'Web', 24.0, 6.0, 2.0, 0)
# ('JOSPEH', 'ALLIS', 'M', '2-26-2014', '01-07-2016', 'Analyst', 22.0, 45364, 'Web', 20.0, 10.0, 2.0, 0)
# ('KING', 'ALIMENT', 'M', '07-05-2013', '01-07-2016', 'Analyst', 22.0, 42013, 'Web', 27.0, 3.0, 4.0, 0)
# ('KURT', 'ACEVEDO', 'M', '7-22-2013', '01-07-2016', 'Analyst', 25.0, 42362, 'Marketing', 24.0, 6.0, 5.0, 2)
# ('LYNNETTE', 'APRUZZESE', 'F', '11-18-2013', '01-07-2016', 'Analyst', 25.0, 44620, 'Finance', 26.0, 4.0, 5.0, 2)
# ('DANIELA', 'ARIAIL', 'F', '8-25-2014', '01-07-2016', 'Analyst', 23.0, 43285, 'Operations', 23.0, 7.0, 5.0, 1)
# ('CARI', 'ARENALES', 'F', '04-10-2014', '01-07-2016', 'Senior Analyst', 28.0, 66338, 'Web', 24.0, 6.0, 3.0, 5)
# ('ANGELITA', 'ARAGUS', 'F', '08-04-2013', '01-07-2016', 'Analyst', 25.0, 46436, 'IT', 27.0, 3.0, 4.0, 2)
# ('ISABELLE', 'ANGERMAN', 'F', '4-19-2013', '01-07-2016', 'Analyst', 24.0, 49705, 'Management', 28.0, 2.0, 3.0, 0)
# ('NORBERT', 'AHALT', 'M', '3-27-2014', '01-07-2016', 'Analyst', 21.0, 40095, 'Management', 19.0, 11.0, 3.0, 0)
# ('PAULINE', 'ALTSHULER', 'F', '12-13-2014', '01-07-2016', 'Senior Analyst', 28.0, 61647, 'Finance', 28.0, 2.0, 4.0, 3)
# ('JANETTE', 'ANEZ', 'F', '8-17-2014', '01-07-2016', 'Analyst', 21.0, 42811, 'Marketing', 22.0, 8.0, 3.0, 0)
# ('CHARLENE', 'AMANO', 'F', '12-25-2013', '01-07-2016', 'Analyst', 25.0, 47365, 'Finance', 15.0, 15.0, 2.0, 2)
# ('HOWARD', 'ABDELWAHED', 'M', '8-20-2013', '01-07-2016', 'Analyst', 22.0, 45721, 'Operations', 18.0, 12.0, 5.0, 0)
# ('PAUL', 'AANENSON', 'M', '07-05-2013', '01-07-2016', 'Analyst', 25.0, 49976, 'Web', 25.0, 5.0, 2.0, 1)
# ('CORTEZ', 'ALLINDER', 'M', '4-19-2013', '01-07-2016', 'Analyst', 21.0, 42650, 'Marketing', 21.0, 9.0, 2.0, 0)
# ('AHMAD', 'ALCANTARA', 'M', '1-18-2015', '01-07-2016', 'Analyst', 25.0, 44632, 'Management', 27.0, 3.0, 3.0, 3)
# ('JONAH', 'ALEWINE', 'M', '7-28-2014', '01-07-2016', 'Analyst', 25.0, 48389, 'Operations', 15.0, 15.0, 3.0, 3)
# ('DARIN', 'AFABLE', 'M', '10-22-2013', '01-07-2016', 'Analyst', 21.0, 48665, 'Operations', 18.0, 12.0, 2.0, 0)
# ('ALONSO', 'ALMANZA', 'M', '04-05-2013', '01-07-2016', 'Associate', 31.0, 72886, 'Management', 21.0, 9.0, 4.0, 6)
# ('RENE', 'ANKLAM', 'F', '06-08-2014', '01-07-2016', 'Analyst', 21.0, 45225, 'IT', 28.0, 2.0, 5.0, 0)
# ('RILEY', 'AIKINS', 'M', '6-16-2013', '01-07-2016', 'Senior Analyst', 25.0, 60712, 'Finance', 26.0, 4.0, 4.0, 0)
# ('WYATT', 'ALBERTS', 'M', '10-07-2013', '01-07-2016', 'Analyst', 24.0, 41290, 'Operations', 17.0, 13.0, 3.0, 1)
# ('KIMBERLEE', 'ARCIGA', 'F', '5-16-2014', '01-07-2016', 'Analyst', 21.0, 44993, 'IT', 18.0, 12.0, 2.0, 0)
# ('KRISTA', 'AMRICH', 'F', '8-21-2013', '01-07-2016', 'Analyst', 24.0, 46118, 'IT', 22.0, 8.0, 4.0, 1)
# ('MARYJANE', 'ARES', 'F', '8-24-2012', '01-07-2016', 'Senior Analyst', 25.0, 65212, 'Management', 29.0, 1.0, 5.0, 1)
# ('SAVANNAH', 'APREA', 'F', '12-20-2011', '01-07-2016', 'Senior Manager', 38.0, 193621, 'Operations', 19.0, 11.0, 4.0, 9)
# ('NATALIE', 'AMALONG', 'F', '11-25-2013', '01-07-2016', 'Analyst', 23.0, 44223, 'Marketing', 19.0, 11.0, 2.0, 0)
# ('MARY', 'ALMESTICA', 'F', '10-12-2013', '01-07-2016', 'Senior Analyst', 27.0, 53339, 'Finance', 26.0, 4.0, 2.0, 1)
# ('KAYLA', 'AMLIN', 'F', '07-07-2014', '01-07-2016', 'Analyst', 24.0, 43638, 'Web', 29.0, 1.0, 3.0, 1)
# ('JULIAN', 'ACKERLEY', 'M', '06-03-2013', '01-07-2016', 'Analyst', 22.0, 44963, 'Marketing', 21.0, 9.0, 2.0, 0)
# ('JO', 'AMBLER', 'F', '05-01-2014', '01-07-2016', 'Analyst', 21.0, 42686, 'Marketing', 22.0, 8.0, 3.0, 0)
# ('KASEY', 'APFEL', 'F', '09-01-2014', '01-07-2016', 'Analyst', 21.0, 40381, 'Web', 22.0, 8.0, 2.0, 0)
# ('IONA', 'ARGALL', 'F', '05-02-2013', '01-07-2016', 'Analyst', 21.0, 48461, 'Finance', 15.0, 15.0, 5.0, 0)
# ('ALBERTA', 'AMIS', 'F', '2-15-2013', '01-07-2016', 'Analyst', 25.0, 46584, 'Marketing', 18.0, 12.0, 4.0, 1)
# ('WILMER', 'AKIONA', 'M', '5-30-2014', '01-07-2016', 'Senior Analyst', 25.0, 50739, 'IT', 25.0, 5.0, 3.0, 0)
# ('MELVIN', 'ABERNATHA', 'M', '7-28-2014', '01-07-2016', 'Associate', 31.0, 82083, 'Management', 17.0, 13.0, 3.0, 5)
# ('CORA', 'AMESQUITA', 'F', '12-22-2014', '01-07-2016', 'Analyst', 23.0, 40324, 'Operations', 27.0, 3.0, 2.0, 1)
# ('EVERETT', 'ACHILLES', 'M', '11-20-2014', '01-07-2016', 'Analyst', 23.0, 44001, 'Management', 26.0, 4.0, 3.0, 1)
# ('DOTTIE', 'ARDREY', 'F', '8-17-2013', '01-07-2016', 'Analyst', 22.0, 43059, 'Management', 30.0, 0.0, 3.0, 0)
# ('CORINE', 'APAEZ', 'F', '9-25-2014', '01-07-2016', 'Analyst', 24.0, 41685, 'Finance', 30.0, 0.0, 2.0, 2)
# ('DARIO', 'ALESSI', 'M', '03-11-2012', '01-07-2016', 'Associate', 28.0, 95982, 'Operations', 26.0, 4.0, 4.0, 0)
# ('HILDA', 'AMBROSIUS', 'F', '6-17-2013', '01-07-2016', 'Analyst', 23.0, 44699, 'Management', 26.0, 4.0, 3.0, 0)
# ('ELOISA', 'ARGIE', 'F', '08-07-2013', '01-07-2016', 'Senior Analyst', 28.0, 52690, 'Marketing', 30.0, 0.0, 5.0, 3)
# ('HEIDI', 'AMAZAN', 'F', '2-15-2014', '01-07-2016', 'Analyst', 21.0, 40041, 'Management', 18.0, 12.0, 4.0, 0)
# ('KATELYN', 'APPENZELLER', 'F', '11-02-2014', '01-07-2016', 'Senior Analyst', 28.0, 56314, 'Finance', 16.0, 14.0, 5.0, 3)
# ('WILLIS', 'ADAN', 'M', '2-16-2014', '01-07-2016', 'Analyst', 25.0, 49785, 'Operations', 26.0, 4.0, 3.0, 2)
# ('RUTH', 'ALO', 'F', '11-21-2013', '01-07-2016', 'Analyst', 24.0, 41284, 'Web', 29.0, 1.0, 5.0, 1)
# ('JOSEFA', 'APPLEWHAITE', 'F', '5-19-2014', '01-07-2016', 'Analyst', 22.0, 40562, 'Finance', 26.0, 4.0, 5.0, 0)
# ('OSCAR', 'ABLING', 'M', '08-01-2013', '01-07-2016', 'Analyst', 22.0, 46741, 'Operations', 30.0, 0.0, 2.0, 0)
# ('ROOSEVELT', 'ADES', 'M', '02-12-2014', '01-07-2016', 'Analyst', 24.0, 45100, 'Operations', 28.0, 2.0, 2.0, 1)
# ('MARVIN', 'ABELS', 'M', '9-15-2014', '01-07-2016', 'Analyst', 22.0, 41712, 'IT', 23.0, 7.0, 5.0, 0)
# ('MARCELLA', 'AMY', 'F', '5-17-2014', '01-07-2016', 'Analyst', 24.0, 47069, 'Operations', 20.0, 10.0, 4.0, 1)
# ('KARL', 'ACCETTURO', 'M', '4-19-2013', '01-07-2016', 'Analyst', 25.0, 40460, 'Web', 28.0, 2.0, 3.0, 1)
# ('WALTER', 'ABATE', 'M', '2-26-2013', '01-07-2016', 'Analyst', 24.0, 47068, 'Finance', 28.0, 2.0, 4.0, 0)
# ('ELIZA', 'ANSBACHER', 'F', '9-30-2013', '01-07-2016', 'Senior Analyst', 25.0, 50813, 'Marketing', 26.0, 4.0, 2.0, 0)
# ('YONG', 'ALDERFER', 'M', '4-22-2010', '01-07-2016', 'Manager', 33.0, 129191, 'Operations', 22.0, 8.0, 4.0, 3)
# ('CARI', 'ARENALES', 'F', '04-10-2014', '01-07-2016', 'Senior Analyst', 28.0, 66338, 'Web', 24.0, 6.0, 3.0, 5)
# ('ALVA', 'ALAMPI', 'M', '12-19-2014', '01-07-2016', 'Analyst', 24.0, 46749, 'Operations', 28.0, 2.0, 5.0, 2)
# ('REINA', 'ARMAGOST', 'F', '10-15-2011', '01-07-2016', 'Manager', 33.0, 108665, 'Finance', 15.0, 15.0, 2.0, 6)
# ('ERICKA', 'ANTHONY', 'F', '12-06-2012', '01-07-2016', 'Associate', 32.0, 76964, 'Management', 23.0, 7.0, 5.0, 5)
# ('LUIGI', 'ALLYNE', 'M', '12-19-2013', '01-07-2016', 'Analyst', 24.0, 47417, 'Marketing', 21.0, 9.0, 3.0, 1)
# ('JEFFEREY', 'ALEXY', 'M', '4-16-2014', '01-07-2016', 'Analyst', 21.0, 47669, 'IT', 25.0, 5.0, 5.0, 0)
# ('ROBERT', 'ARCAND', 'F', '6-16-2014', '01-07-2016', 'Analyst', 21.0, 40318, 'Finance', 20.0, 10.0, 3.0, 0)
# ('HAYWOOD', 'ALKINS', 'M', '09-01-2013', '01-07-2016', 'Analyst', 23.0, 46743, 'IT', 17.0, 13.0, 2.0, 0)
# ('STAN', 'AGRESTO', 'M', '05-08-2014', '01-07-2016', 'Analyst', 25.0, 40060, 'Management', 20.0, 10.0, 2.0, 2)
# ('BETTIE', 'ANDUJAR', 'F', '10-20-2013', '01-07-2016', 'Analyst', 25.0, 46129, 'Management', 20.0, 10.0, 3.0, 2)
# ('ALLAN', 'ACEVES', 'M', '04-09-2013', '01-07-2016', 'Senior Manager', 38.0, 189435, 'Marketing', 19.0, 11.0, 4.0, 10)
# ('ELEANORE', 'ARENA', 'F', '3-20-2013', '01-07-2016', 'Senior Analyst', 26.0, 62537, 'Management', 27.0, 3.0, 2.0, 0)
# ('ERIC', 'ABAJIAN', 'M', '9-17-2013', '01-07-2016', 'Analyst', 24.0, 44145, 'Management', 17.0, 13.0, 5.0, 1)
# ('LEIGH', 'ANAWALT', 'F', '10-02-2014', '01-07-2016', 'Analyst', 22.0, 47998, 'Marketing', 23.0, 7.0, 5.0, 0)
# ('ARON', 'ALBOR', 'M', '1-17-2014', '01-07-2016', 'Analyst', 25.0, 49310, 'Marketing', 16.0, 14.0, 2.0, 2)
# ('KAREN', 'ALMSTEAD', 'F', '3-21-2014', '01-07-2016', 'Analyst', 24.0, 49235, 'Management', 17.0, 13.0, 4.0, 1)
# ('KENDRICK', 'AHIMUD', 'M', '4-26-2013', '01-07-2016', 'Senior Analyst', 26.0, 68245, 'Finance', 26.0, 4.0, 3.0, 0)
# ('LAKESHA', 'ARDEN', 'F', '10-19-2014', '01-07-2016', 'Analyst', 23.0, 47498, 'Finance', 25.0, 5.0, 5.0, 1)
# ('JUNIOR', 'AGORAS', 'M', '11-30-2014', '01-07-2016', 'Analyst', 25.0, 40636, 'Finance', 26.0, 4.0, 4.0, 3)
# ('ERNESTINE', 'AMUSO', 'F', '01-03-2013', '01-07-2016', 'Analyst', 25.0, 45233, 'Operations', 25.0, 5.0, 4.0, 1)
# ('TERESITA', 'ARENTZ', 'F', '11-03-2013', '01-07-2016', 'Senior Analyst', 27.0, 53275, 'Finance', 16.0, 14.0, 4.0, 4)
# ('ESTHER', 'ALTSCHULER', 'F', '7-18-2013', '01-07-2016', 'Analyst', 24.0, 43540, 'Web', 17.0, 13.0, 5.0, 1)
# ('BERRY', 'ALDONZA', 'M', '1-20-2015', '01-07-2016', 'Analyst', 21.0, 40275, 'Management', 30.0, 0.0, 5.0, 0)
# ('WENDELL', 'ACREE', 'M', '12-11-2013', '01-07-2016', 'Analyst', 21.0, 44361, 'Web', 28.0, 2.0, 5.0, 0)
# ('RUBEN', 'ABSHEAR', 'M', '5-20-2013', '01-07-2016', 'Analyst', 25.0, 41936, 'Web', 16.0, 14.0, 2.0, 1)
# ('PATTIE', 'ARGUIN', 'F', '4-13-2013', '01-07-2016', 'Analyst', 21.0, 45830, 'Finance', 25.0, 5.0, 5.0, 0)
# ('ISABEL', 'AMICI', 'F', '7-23-2013', '01-07-2016', 'Analyst', 23.0, 44521, 'Web', 28.0, 2.0, 3.0, 0)
# ('BRODERICK', 'ALMERICO', 'M', '08-04-2014', '01-07-2016', 'Analyst', 22.0, 45997, 'Management', 18.0, 12.0, 3.0, 0)
# ('JEREMY', 'ABDELLA', 'M', '12-07-2013', '01-07-2016', 'Analyst', 25.0, 44218, 'Finance', 19.0, 11.0, 2.0, 2)
# ('KELLI', 'AMORIELLO', 'F', '10-07-2013', '01-07-2016', 'Manager', 35.0, 140926, 'Finance', 28.0, 2.0, 2.0, 12)
# ('MARIETTA', 'APPLEBAUM', 'F', '09-03-2014', '01-07-2016', 'Analyst', 21.0, 48886, 'Operations', 23.0, 7.0, 3.0, 0)
# ('CHADWICK', 'ALATOSSE', 'M', '09-11-2014', '01-07-2016', 'Analyst', 23.0, 49081, 'Operations', 26.0, 4.0, 3.0, 1)
# ('NONA', 'APODACA', 'F', '2-26-2014', '01-07-2016', 'Analyst', 23.0, 42195, 'Operations', 28.0, 2.0, 2.0, 0)
# ('JON', 'ABOLT', 'M', '02-01-2013', '01-07-2016', 'Senior Analyst', 25.0, 50130, 'Marketing', 22.0, 8.0, 3.0, 0)
# ('JORDON', 'ALLARA', 'M', '12-01-2014', '01-07-2016', 'Senior Analyst', 25.0, 55472, 'Finance', 30.0, 0.0, 3.0, 0)
# ('LAWRENCE', 'ABBOT', 'M', '5-21-2013', '01-07-2016', 'Analyst', 25.0, 43269, 'Operations', 17.0, 13.0, 5.0, 1)
# ('LEANNE', 'ANNABEL', 'F', '9-23-2013', '01-07-2016', 'Analyst', 22.0, 43712, 'Operations', 17.0, 13.0, 2.0, 0)
# ('LES', 'ALCIVAR', 'M', '12-07-2014', '01-07-2016', 'Analyst', 25.0, 42377, 'Marketing', 24.0, 6.0, 5.0, 3)
# ('DEIDRA', 'ARCHANGEL', 'F', '10-05-2012', '01-07-2016', 'Senior Analyst', 28.0, 69316, 'Operations', 24.0, 6.0, 3.0, 0)
# ('GERI', 'ARDENEAUX', 'F', '8-27-2013', '01-07-2016', 'Analyst', 23.0, 46418, 'Marketing', 29.0, 1.0, 2.0, 0)
# ('MANUAL', 'ALLFORD', 'M', '8-14-2014', '01-07-2016', 'Senior Analyst', 28.0, 65566, 'Marketing', 17.0, 13.0, 3.0, 5)
# ('CELESTINE', 'ARGIRO', 'F', '10-19-2013', '01-07-2016', 'Analyst', 24.0, 48976, 'Finance', 25.0, 5.0, 2.0, 1)
# ('JAVIER', 'ACEDO', 'M', '4-15-2013', '01-07-2016', 'Analyst', 23.0, 43760, 'Marketing', 24.0, 6.0, 4.0, 0)
# ('CAREN', 'ARGO', 'F', '5-20-2013', '01-07-2016', 'Analyst', 22.0, 41047, 'Operations', 21.0, 9.0, 4.0, 0)
# ('DEBBIE', 'ALUARADO', 'F', '12-08-2013', '01-07-2016', 'Analyst', 25.0, 43225, 'Operations', 30.0, 0.0, 2.0, 2)
# ('MICHAEL', 'AAGAARD', 'M', '1-21-2015', '01-07-2016', 'Analyst', 22.0, 42361, 'Marketing', 25.0, 5.0, 2.0, 0)
# ('MARLENE', 'AMAYA', 'F', '9-15-2014', '01-07-2016', 'Analyst', 22.0, 43835, 'Management', 26.0, 4.0, 4.0, 0)
# ('HESTER', 'ARAGAO', 'F', '02-07-2014', '01-07-2016', 'Analyst', 25.0, 47326, 'Operations', 24.0, 6.0, 5.0, 2)
# ('ULYSSES', 'AILTS', 'M', '9-28-2012', '01-07-2016', 'Senior Analyst', 25.0, 61221, 'Marketing', 19.0, 11.0, 3.0, 0)
# ('INES', 'ARB', 'F', '12-30-2013', '01-07-2016', 'Analyst', 21.0, 42943, 'Finance', 17.0, 13.0, 4.0, 0)
# ('JESSE', 'ABDULKARIM', 'M', '09-04-2013', '01-07-2016', 'Analyst', 23.0, 48751, 'Operations', 24.0, 6.0, 3.0, 0)
# ('CLAY', 'AERTS', 'M', '6-22-2013', '01-07-2016', 'Analyst', 22.0, 42136, 'Finance', 23.0, 7.0, 4.0, 0)
# ('MERCEDES', 'ANASTASI', 'F', '6-24-2013', '01-07-2016', 'Analyst', 21.0, 42472, 'Web', 27.0, 3.0, 5.0, 0)
# ('BRANDON', 'ABBY', 'M', '3-23-2013', '01-07-2016', 'Analyst', 22.0, 46677, 'IT', 26.0, 4.0, 4.0, 0)
# ('BILL', 'ABOSHIHATA', 'M', '12-03-2014', '01-07-2016', 'Analyst', 25.0, 45977, 'Web', 28.0, 2.0, 5.0, 3)
# ('ALFREDO', 'ACHZIGER', 'M', '11-25-2014', '01-07-2016', 'Analyst', 25.0, 41345, 'Web', 18.0, 12.0, 5.0, 3)
# ('NICOLE', 'ALSOBROOK', 'F', '6-27-2010', '01-07-2016', 'Director', 41.0, 323196, 'Marketing', 23.0, 7.0, 3.0, 10)
# ('GOLDIE', 'ANERTON', 'F', '10-16-2014', '01-07-2016', 'Analyst', 22.0, 42727, 'Marketing', 19.0, 11.0, 2.0, 0)
# ('ELIAS', 'ADSIT', 'M', '5-27-2012', '01-07-2016', 'Senior Analyst', 25.0, 53218, 'Marketing', 18.0, 12.0, 5.0, 0)
# ('SUN', 'ARDIZZONE', 'F', '07-12-2013', '01-07-2016', 'Analyst', 21.0, 48422, 'IT', 21.0, 9.0, 3.0, 0)
# ('BOOKER', 'AKRIGHT', 'M', '10-14-2013', '01-07-2016', 'Associate', 32.0, 83066, 'IT', 23.0, 7.0, 4.0, 6)
# ('LEEANN', 'ARCHILA', 'F', '9-22-2013', '01-07-2016', 'Analyst', 21.0, 41627, 'Operations', 29.0, 1.0, 2.0, 0)
# ('DEREK', 'ABOULISSAN', 'M', '2-13-2013', '01-07-2016', 'Director', 42.0, 388112, 'Marketing', 27.0, 3.0, 2.0, 18)
# ('DAWN', 'ALTIER', 'F', '11-12-2013', '01-07-2016', 'Analyst', 23.0, 44469, 'Web', 25.0, 5.0, 3.0, 0)
# ('SHELTON', 'AKUCHIE', 'M', '11-07-2014', '01-07-2016', 'Analyst', 24.0, 41109, 'Marketing', 23.0, 7.0, 3.0, 2)
# ('LEOPOLDO', 'ALBORN', 'M', '12-03-2014', '01-07-2016', 'Analyst', 23.0, 43924, 'Operations', 27.0, 3.0, 4.0, 1)
# ('DARREN', 'ACERO', 'M', '12-26-2013', '01-07-2016', 'Senior Analyst', 25.0, 64232, 'Operations', 23.0, 7.0, 4.0, 2)
# ('ARMANDO', 'ACHENBACH', 'M', '3-23-2013', '01-07-2016', 'Analyst', 22.0, 49644, 'Operations', 19.0, 11.0, 2.0, 0)
# ('DELPHINE', 'AREVALO', 'F', '1-23-2009', '01-07-2016', 'Director', 43.0, 284733, 'Web', 15.0, 15.0, 2.0, 11)
# ('IDA', 'ALVIRA', 'F', '3-17-2014', '01-07-2016', 'Analyst', 22.0, 48802, 'Operations', 20.0, 10.0, 4.0, 0)
# ('ALECIA', 'ARIANO', 'F', '12-13-2013', '01-07-2016', 'Analyst', 21.0, 41748, 'IT', 21.0, 9.0, 4.0, 0)
# ('JUAN', 'ABBASSI', 'M', '07-01-2013', '01-07-2016', 'Senior Analyst', 27.0, 61575, 'Finance', 20.0, 10.0, 2.0, 1)
# ('YOLANDA', 'ALWAN', 'F', '12-17-2013', '01-07-2016', 'Analyst', 24.0, 46062, 'Marketing', 25.0, 5.0, 3.0, 1)
# ('EMMA', 'ALTSISI', 'F', '04-02-2013', '01-07-2016', 'Analyst', 25.0, 40251, 'Finance', 18.0, 12.0, 2.0, 1)
# ('OCTAVIO', 'ALAMEIDA', 'M', '12-09-2014', '01-07-2016', 'Analyst', 21.0, 42416, 'Management', 16.0, 14.0, 2.0, 0)
# ('LEILA', 'ANNUNZIATA', 'F', '5-30-2014', '01-07-2016', 'Analyst', 22.0, 43951, 'Finance', 18.0, 12.0, 5.0, 0)
# ('CECIL', 'ABUD', 'M', '01-10-2014', '01-07-2016', 'Analyst', 25.0, 47903, 'Finance', 19.0, 11.0, 2.0, 2)
# ('CHARLES', 'ARMSTER', 'F', '05-07-2013', '01-07-2016', 'Analyst', 22.0, 45275, 'Operations', 27.0, 3.0, 3.0, 0)
# ('FELIX', 'ACHESON', 'M', '9-16-2014', '01-07-2016', 'Senior Analyst', 26.0, 61046, 'Finance', 28.0, 2.0, 5.0, 1)
# ('JAQUELINE', 'AREHART', 'F', '01-04-2014', '01-07-2016', 'Analyst', 25.0, 48204, 'Web', 15.0, 15.0, 4.0, 2)
# ('GALE', 'ANNARUMO', 'F', '6-23-2013', '01-07-2016', 'Senior Analyst', 27.0, 51053, 'Operations', 23.0, 7.0, 3.0, 1)
# ('FRANCIS', 'ABERSON', 'M', '9-28-2014', '01-07-2016', 'Analyst', 22.0, 42560, 'Operations', 16.0, 14.0, 2.0, 0)
# ('TAMMI', 'APADACA', 'F', '12-02-2014', '01-07-2016', 'Analyst', 25.0, 40947, 'Marketing', 20.0, 10.0, 2.0, 3)
# ('LOUELLA', 'ARBRY', 'F', '06-04-2012', '01-07-2016', 'Senior Analyst', 28.0, 68432, 'IT', 30.0, 0.0, 2.0, 0)
# ('JOYCE', 'ALQUIJAY', 'F', '5-28-2014', '01-07-2016', 'Analyst', 24.0, 44561, 'Management', 24.0, 6.0, 4.0, 1)
# ('MARGUERITE', 'AMICK', 'F', '2-13-2012', '01-07-2016', 'Senior Analyst', 26.0, 63882, 'Operations', 27.0, 3.0, 2.0, 1)
# ('KENTON', 'ALEXANDRA', 'M', '12-11-2013', '01-07-2016', 'Analyst', 23.0, 45903, 'Finance', 21.0, 9.0, 2.0, 0)
# ('CODY', 'ACEUEDO', 'M', '01-01-2013', '01-07-2016', 'Analyst', 23.0, 48470, 'Web', 28.0, 2.0, 3.0, 0)
# ('FRANKIE', 'ANETSBERGER', 'F', '1-28-2014', '01-07-2016', 'Analyst', 23.0, 45704, 'Finance', 24.0, 6.0, 4.0, 0)
# ('MILLICENT', 'ARAMBOLES', 'F', '12-21-2013', '01-07-2016', 'Senior Analyst', 25.0, 57064, 'Management', 18.0, 12.0, 5.0, 0)
# ('DEE', 'ALEVEDO', 'M', '4-13-2014', '01-07-2016', 'Analyst', 22.0, 48546, 'IT', 15.0, 15.0, 2.0, 0)
# ('ZELMA', 'ANTONELLI', 'F', '9-28-2013', '01-07-2016', 'Senior Analyst', 28.0, 50044, 'Operations', 25.0, 5.0, 3.0, 5)
# ('PEARL', 'AMARA', 'F', '6-24-2013', '01-07-2016', 'Analyst', 21.0, 41604, 'Marketing', 16.0, 14.0, 2.0, 0)
# ('CARIDAD', 'ARMWOOD', 'F', '06-11-2014', '01-07-2016', 'Analyst', 23.0, 45022, 'Finance', 23.0, 7.0, 3.0, 0)
# ('ELDON', 'AGOFF', 'M', '09-11-2011', '01-07-2016', 'Manager', 33.0, 107432, 'Web', 24.0, 6.0, 4.0, 8)
# ('SHANDA', 'ARJONA', 'F', '2-28-2013', '01-07-2016', 'Analyst', 24.0, 45499, 'IT', 26.0, 4.0, 4.0, 0)
# ('HEATH', 'AGNES', 'M', '04-12-2013', '01-07-2016', 'Analyst', 22.0, 47846, 'Marketing', 26.0, 4.0, 2.0, 0)
# ('ROCIO', 'ARCURI', 'F', '09-07-2012', '01-07-2016', 'Senior Analyst', 28.0, 67299, 'Operations', 29.0, 1.0, 3.0, 1)
# ('MARJORIE', 'ALTRECHE', 'F', '11-26-2014', '01-07-2016', 'Analyst', 24.0, 48047, 'Web', 21.0, 9.0, 2.0, 2)
# ('CYRUS', 'ALANIS', 'M', '12-06-2010', '01-07-2016', 'Senior Manager', 36.0, 186356, 'Finance', 20.0, 10.0, 3.0, 8)
# ('ISABELL', 'ARKINS', 'F', '11-23-2013', '01-07-2016', 'Analyst', 22.0, 48539, 'Operations', 26.0, 4.0, 5.0, 0)
# ('ROBBIE', 'ANGUS', 'F', '12-13-2014', '01-07-2016', 'Analyst', 22.0, 45146, 'Marketing', 18.0, 12.0, 2.0, 0)
# ('TIFFANY', 'ALTIZER', 'F', '02-01-2012', '01-07-2016', 'Senior Analyst', 25.0, 67321, 'IT', 26.0, 4.0, 3.0, 0)
# ('JODIE', 'ANIELLO', 'F', '10-29-2014', '01-07-2016', 'Analyst', 24.0, 43137, 'IT', 27.0, 3.0, 2.0, 2)
# ('MARCY', 'ANNICCHIARICO', 'F', '05-03-2013', '01-07-2016', 'Analyst', 24.0, 46974, 'Web', 30.0, 0.0, 4.0, 0)
# ('WILHELMINA', 'AREND', 'F', '05-03-2013', '01-07-2016', 'Analyst', 25.0, 48602, 'Marketing', 30.0, 0.0, 2.0, 1)
# ('NORA', 'AMBROZIAK', 'F', '9-23-2013', '01-07-2016', 'Analyst', 22.0, 43036, 'Web', 25.0, 5.0, 4.0, 0)
# ('JAIME', 'ACHTERHOF', 'M', '07-08-2014', '01-07-2016', 'Analyst', 23.0, 49318, 'Finance', 17.0, 13.0, 3.0, 0)
# ('CHRISTA', 'ANENE', 'F', '06-10-2013', '01-07-2016', 'Analyst', 23.0, 48356, 'Web', 19.0, 11.0, 2.0, 0)
# ('BRADLEY', 'ABES', 'M', '6-25-2013', '01-07-2016', 'Analyst', 25.0, 49894, 'Operations', 22.0, 8.0, 3.0, 1)
# ('LUCILE', 'ANNA', 'F', '12-19-2014', '01-07-2016', 'Analyst', 24.0, 42344, 'Marketing', 17.0, 13.0, 4.0, 2)
# ('LYNDON', 'ALFREDS', 'M', '1-16-2013', '01-07-2016', 'Analyst', 24.0, 43343, 'Web', 27.0, 3.0, 4.0, 0)
# ('DARA', 'ARIEL', 'F', '12-29-2013', '01-07-2016', 'Analyst', 22.0, 47750, 'Operations', 27.0, 3.0, 4.0, 0)
# ('KENT', 'ACKMANN', 'M', '6-21-2014', '01-07-2016', 'Analyst', 22.0, 42440, 'Marketing', 19.0, 11.0, 3.0, 0)
# ('ANTIONETTE', 'ARCHEY', 'F', '7-23-2014', '01-07-2016', 'Analyst', 25.0, 45236, 'Web', 16.0, 14.0, 2.0, 3)
# ('OTIS', 'ACTON', 'M', '4-23-2013', '01-07-2016', 'Analyst', 24.0, 41514, 'Operations', 27.0, 3.0, 4.0, 0)
# ('CHANCE', 'ALBERICO', 'M', '01-02-2015', '01-07-2016', 'Analyst', 23.0, 45084, 'IT', 24.0, 6.0, 4.0, 1)
# ('CONNIE', 'ALTIERI', 'F', '12-21-2013', '01-07-2016', 'Analyst', 24.0, 41676, 'Marketing', 29.0, 1.0, 3.0, 1)
# ('ANGELIA', 'ANHORN', 'F', '09-08-2013', '01-07-2016', 'Analyst', 23.0, 46127, 'Marketing', 28.0, 2.0, 5.0, 0)
# ('SHIRLEY', 'ALDRIDGE', 'M', '3-17-2012', '01-07-2016', 'Associate', 29.0, 99416, 'Management', 20.0, 10.0, 5.0, 4)
# ('TESSIE', 'ARGULEWICZ', 'F', '5-27-2013', '01-07-2016', 'Analyst', 25.0, 47899, 'Operations', 15.0, 15.0, 3.0, 1)
# ('DARCY', 'ANTONUCCI', 'F', '12-08-2013', '01-07-2016', 'Analyst', 23.0, 45927, 'Finance', 15.0, 15.0, 3.0, 0)
# ('CARMINE', 'ALARIE', 'M', '11-11-2014', '01-07-2016', 'Analyst', 23.0, 48891, 'Management', 22.0, 8.0, 2.0, 1)
# ('SANFORD', 'AITA', 'M', '4-30-2013', '01-07-2016', 'Analyst', 22.0, 41284, 'Finance', 19.0, 11.0, 5.0, 0)
# ('MICHEAL', 'ABLEMAN', 'M', '4-20-2011', '01-07-2016', 'Director', 43.0, 313649, 'IT', 21.0, 9.0, 2.0, 17)
# ('ROLLAND', 'ALEXANDERS', 'M', '01-06-2013', '01-07-2016', 'Analyst', 22.0, 49111, 'Marketing', 22.0, 8.0, 2.0, 0)
# ('KRIS', 'AHNELL', 'M', '2-20-2012', '01-07-2016', 'Senior Analyst', 25.0, 51509, 'Marketing', 23.0, 7.0, 3.0, 0)
# ('CHET', 'ALGER', 'M', '12-23-2014', '01-07-2016', 'Analyst', 21.0, 49393, 'IT', 16.0, 14.0, 3.0, 0)
# ('TYRELL', 'ALFREDO', 'M', '7-14-2013', '01-07-2016', 'Analyst', 21.0, 46580, 'Web', 27.0, 3.0, 4.0, 0)
# ('ANGELICA', 'AMSBAUGH', 'F', '2-23-2014', '01-07-2016', 'Analyst', 25.0, 44538, 'Finance', 16.0, 14.0, 4.0, 2)
# ('MARIE', 'ALPHONSO', 'F', '12-27-2013', '01-07-2016', 'Analyst', 21.0, 46507, 'Finance', 22.0, 8.0, 2.0, 0)
# ('NOLA', 'ANSELMI', 'F', '12-09-2013', '01-07-2016', 'Analyst', 24.0, 47308, 'Web', 26.0, 4.0, 5.0, 1)
# ('JED', 'ALEQUIN', 'M', '11-18-2014', '01-07-2016', 'Analyst', 22.0, 45952, 'Management', 25.0, 5.0, 5.0, 0)
# ('BOBBIE', 'AIDT', 'M', '6-29-2013', '01-07-2016', 'Senior Analyst', 25.0, 68505, 'Operations', 15.0, 15.0, 3.0, 1)
# ('EMILY', 'ALTHISER', 'F', '2-26-2013', '01-07-2016', 'Senior Analyst', 26.0, 65316, 'Marketing', 21.0, 9.0, 5.0, 0)
# ('GENARO', 'ALAM', 'M', '12-12-2014', '01-07-2016', 'Analyst', 23.0, 47401, 'Marketing', 17.0, 13.0, 5.0, 1)
# ('LUANN', 'APERGES', 'F', '11-03-2013', '01-07-2016', 'Manager', 35.0, 129017, 'Operations', 25.0, 5.0, 3.0, 11)
# ('ELISA', 'ANDONIAN', 'F', '12-27-2014', '01-07-2016', 'Analyst', 23.0, 46347, 'Finance', 28.0, 2.0, 4.0, 1)
# ('DAN', 'ABRAMOVITZ', 'M', '3-25-2014', '01-07-2016', 'Analyst', 25.0, 47573, 'Web', 25.0, 5.0, 4.0, 2)
# ('WILFRED', 'ADOLPHSEN', 'M', '10-22-2011', '01-07-2016', 'Associate', 32.0, 97708, 'IT', 29.0, 1.0, 2.0, 5)
# ('LEONEL', 'AKERSON', 'M', '6-21-2014', '01-07-2016', 'Analyst', 21.0, 46002, 'Finance', 21.0, 9.0, 5.0, 0)
# ('CLAIRE', 'AMERMAN', 'F', '02-07-2013', '01-07-2016', 'Analyst', 25.0, 47201, 'IT', 27.0, 3.0, 5.0, 1)
# ('ROGELIO', 'ADRIEN', 'M', '1-15-2014', '01-07-2016', 'Analyst', 21.0, 46733, 'Web', 15.0, 15.0, 2.0, 0)
# ('SHARLENE', 'ARBUTHNOT', 'F', '09-05-2014', '01-07-2016', 'Senior Manager', 39.0, 191793, 'IT', 20.0, 10.0, 3.0, 17)
# ('BOBBIE', 'AIDT', 'M', '6-29-2013', '01-07-2016', 'Senior Analyst', 25.0, 68505, 'Operations', 15.0, 15.0, 3.0, 1)
# ('HOYT', 'ALKEN', 'M', '9-16-2014', '01-07-2016', 'Analyst', 22.0, 41035, 'Management', 19.0, 11.0, 4.0, 0)
# ('ALVINA', 'ARISA', 'F', '9-14-2013', '01-07-2016', 'Manager', 34.0, 126871, 'Management', 16.0, 14.0, 4.0, 7)
# ('JULIET', 'ARABIE', 'F', '4-30-2013', '01-07-2016', 'Senior Analyst', 27.0, 51532, 'Marketing', 25.0, 5.0, 5.0, 0)
# ('ADELE', 'ANDRESEN', 'F', '02-06-2014', '01-07-2016', 'Analyst', 24.0, 43339, 'Finance', 28.0, 2.0, 5.0, 1)
# ('STANFORD', 'ALEYANDREZ', 'M', '5-22-2014', '01-07-2016', 'Analyst', 22.0, 44506, 'IT', 30.0, 0.0, 4.0, 0)
# ('KIETH', 'ALCOMBRIGHT', 'M', '10-20-2013', '01-07-2016', 'Analyst', 23.0, 40045, 'Management', 25.0, 5.0, 2.0, 0)
# ('TOD', 'ALEGAR', 'M', '2-20-2013', '01-07-2016', 'Analyst', 24.0, 48938, 'Finance', 19.0, 11.0, 2.0, 0)
# ('KIRBY', 'AKAHI', 'M', '10-05-2013', '01-07-2016', 'Analyst', 23.0, 48185, 'IT', 19.0, 11.0, 4.0, 0)
# ('MAE', 'AMENTLER', 'F', '4-22-2014', '01-07-2016', 'Analyst', 25.0, 47579, 'Marketing', 25.0, 5.0, 3.0, 2)
# ('DOMINIQUE', 'ANKER', 'F', '8-19-2009', '01-07-2016', 'Director', 41.0, 375647, 'Finance', 20.0, 10.0, 5.0, 14)
# ('SHARON', 'ALOAN', 'F', '04-03-2013', '01-07-2016', 'Analyst', 24.0, 47386, 'Management', 23.0, 7.0, 2.0, 0)
# ('DEVIN', 'ADERHOLT', 'M', '03-01-2014', '01-07-2016', 'Analyst', 24.0, 43952, 'Finance', 23.0, 7.0, 4.0, 1)
# ('JULIETTE', 'APPLEMAN', 'F', '03-06-2013', '01-07-2016', 'Analyst', 24.0, 48981, 'Finance', 26.0, 4.0, 4.0, 0)
# ('SALLY', 'ALVERAZ', 'F', '3-17-2013', '01-07-2016', 'Analyst', 25.0, 40702, 'Marketing', 30.0, 0.0, 4.0, 1)
# ('NELLIE', 'AMAUTY', 'F', '08-10-2014', '01-07-2016', 'Director', 43.0, 235565, 'Web', 20.0, 10.0, 4.0, 17)
# ('BENNIE', 'ARDRY', 'F', '4-24-2014', '01-07-2016', 'Analyst', 22.0, 41641, 'Web', 28.0, 2.0, 4.0, 0)
# ('BRETT', 'ABSHER', 'M', '4-26-2013', '01-07-2016', 'Analyst', 21.0, 44350, 'Finance', 25.0, 5.0, 4.0, 0)
# ('GUSSIE', 'ARCORACI', 'F', '11-18-2013', '01-07-2016', 'Analyst', 23.0, 48887, 'Operations', 26.0, 4.0, 4.0, 0)
# ('DWIGHT', 'ACHEKIAN', 'M', '5-26-2013', '01-07-2016', 'Analyst', 24.0, 47499, 'Web', 24.0, 6.0, 2.0, 0)
# ('MICHELLE', 'ALOE', 'F', '6-16-2013', '01-07-2016', 'Analyst', 25.0, 42128, 'Finance', 18.0, 12.0, 5.0, 1)
# ('STEVIE', 'ALANO', 'M', '2-21-2013', '01-07-2016', 'Analyst', 24.0, 48271, 'Finance', 29.0, 1.0, 3.0, 0)
# ('MISSY', 'ARMISTEAD', 'F', '10-06-2013', '01-07-2016', 'Analyst', 23.0, 41029, 'Management', 19.0, 11.0, 4.0, 0)
# ('MIRNA', 'ARMENTROUT', 'F', '01-04-2015', '01-07-2016', 'Analyst', 25.0, 43659, 'Web', 15.0, 15.0, 5.0, 3)
# ('ANGELO', 'ADAMCIK', 'M', '3-26-2014', '01-07-2016', 'Manager', 33.0, 140867, 'IT', 27.0, 3.0, 4.0, 7)
# ('JUDI', 'ARCHDALE', 'F', '5-22-2014', '01-07-2016', 'Analyst', 24.0, 49806, 'IT', 22.0, 8.0, 5.0, 1)
# ('JODI', 'AMISTADI', 'F', '8-13-2013', '01-07-2016', 'Analyst', 24.0, 49110, 'IT', 25.0, 5.0, 2.0, 1)
# ('EDGARDO', 'ALDO', 'M', '05-04-2014', '01-07-2016', 'Analyst', 23.0, 42081, 'Management', 23.0, 7.0, 4.0, 0)
# ('CHRISTINA', 'ALSON', 'F', '04-03-2013', '01-07-2016', 'Analyst', 21.0, 41017, 'IT', 27.0, 3.0, 5.0, 0)
# ('JESSIE', 'AMALFITANO', 'F', '03-03-2013', '01-07-2016', 'Analyst', 24.0, 48869, 'IT', 26.0, 4.0, 5.0, 0)
# ('NOAH', 'ADZHABAKYAN', 'M', '8-29-2013', '01-07-2016', 'Senior Analyst', 28.0, 66965, 'Web', 16.0, 14.0, 3.0, 5)
# ('JAMAL', 'AGUELE', 'M', '05-12-2013', '01-07-2016', 'Analyst', 24.0, 42338, 'Management', 22.0, 8.0, 4.0, 0)
# ('MARY', 'AIROLA', 'M', '08-06-2013', '01-07-2016', 'Analyst', 22.0, 49380, 'Management', 25.0, 5.0, 4.0, 0)
# ('SUZETTE', 'APADOCA', 'F', '1-25-2014', '01-07-2016', 'Manager', 33.0, 117354, 'Management', 26.0, 4.0, 3.0, 6)
# ('CASANDRA', 'ARAGONI', 'F', '07-12-2013', '01-07-2016', 'Analyst', 25.0, 41679, 'Web', 20.0, 10.0, 2.0, 2)
# ('HARLAND', 'ALLSOP', 'M', '9-18-2014', '01-07-2016', 'Analyst', 22.0, 44207, 'Finance', 28.0, 2.0, 4.0, 0)
# ('EVELYN', 'ALSBERRY', 'F', '10-25-2014', '01-07-2016', 'Analyst', 22.0, 45059, 'Management', 29.0, 1.0, 2.0, 0)
# ('PAULA', 'ALTEW', 'F', '05-09-2011', '01-07-2016', 'Associate', 29.0, 95056, 'Operations', 15.0, 15.0, 3.0, 0)
# ('DAVIS', 'AINGE', 'M', '03-05-2013', '01-07-2016', 'Analyst', 22.0, 48777, 'Management', 29.0, 1.0, 3.0, 0)
# ('DOLLIE', 'ANZIDEO', 'F', '7-28-2014', '01-07-2016', 'Senior Analyst', 28.0, 56728, 'IT', 16.0, 14.0, 4.0, 4)
# ('KERRIE', 'ARMER', 'F', '12-10-2012', '01-07-2016', 'Senior Analyst', 28.0, 53113, 'Finance', 20.0, 10.0, 3.0, 1)
# ('LELIA', 'ARAGONES', 'F', '06-02-2014', '01-07-2016', 'Analyst', 21.0, 45039, 'Management', 19.0, 11.0, 4.0, 0)
# ('BRIGITTE', 'ARBERTHA', 'F', '5-27-2014', '01-07-2016', 'Analyst', 21.0, 41619, 'Management', 21.0, 9.0, 2.0, 0)
# ('CORNELIA', 'ANNUZZI', 'F', '12-17-2013', '01-07-2016', 'Senior Analyst', 26.0, 62672, 'Management', 28.0, 2.0, 3.0, 1)
# ('GINO', 'ALDINGER', 'M', '4-18-2013', '01-07-2016', 'Analyst', 23.0, 42925, 'Management', 26.0, 4.0, 3.0, 0)
# ('SHEILA', 'ALTOMONTE', 'F', '6-13-2013', '01-07-2016', 'Analyst', 25.0, 44343, 'Marketing', 28.0, 2.0, 5.0, 1)
# ('KARA', 'AMPARAN', 'F', '5-17-2014', '01-07-2016', 'Analyst', 22.0, 47967, 'Finance', 23.0, 7.0, 4.0, 0)
# ('CHUNG', 'ALIAGA', 'M', '2-22-2014', '01-07-2016', 'Associate', 30.0, 92323, 'Marketing', 30.0, 0.0, 5.0, 4)
# ('DOMINIQUE', 'AKRE', 'M', '7-23-2013', '01-07-2016', 'Analyst', 25.0, 42002, 'Marketing', 25.0, 5.0, 5.0, 2)
# ('MABEL', 'AMBRIZ', 'F', '1-21-2014', '01-07-2016', 'Senior Manager', 38.0, 199577, 'Marketing', 15.0, 15.0, 5.0, 11)
# ('AMBER', 'ALTY', 'F', '06-09-2011', '01-07-2016', 'Associate', 30.0, 96478, 'Marketing', 29.0, 1.0, 4.0, 0)
# ('SONNY', 'AKSOY', 'M', '09-04-2014', '01-07-2016', 'Senior Analyst', 25.0, 51817, 'IT', 21.0, 9.0, 3.0, 3)
# ('NANNIE', 'ANTLE', 'F', '11-13-2014', '01-07-2016', 'Analyst', 24.0, 45604, 'Web', 20.0, 10.0, 4.0, 2)
# ('WESLEY', 'ABRAHAMSEN', 'M', '4-15-2014', '01-07-2016', 'Analyst', 25.0, 46844, 'Operations', 19.0, 11.0, 5.0, 2)
# ('FRIEDA', 'ANGUIANO', 'F', '12-05-2013', '01-07-2016', 'Analyst', 23.0, 46425, 'Operations', 21.0, 9.0, 2.0, 0)
# ('LISA', 'ALMOS', 'F', '2-24-2014', '01-07-2016', 'Analyst', 21.0, 41908, 'Operations', 18.0, 12.0, 5.0, 0)
# ('ANNA', 'ALOY', 'F', '06-05-2013', '01-07-2016', 'Analyst', 22.0, 42848, 'Web', 29.0, 1.0, 3.0, 0)
# ('CARLTON', 'ADAMIAK', 'M', '01-03-2014', '01-07-2016', 'Analyst', 21.0, 45895, 'Marketing', 17.0, 13.0, 2.0, 0)
# ('PAULINA', 'ARMBRISTER', 'F', '06-02-2013', '01-07-2016', 'Analyst', 22.0, 41580, 'Finance', 20.0, 10.0, 5.0, 0)
# ('KELVIN', 'ADDARIO', 'M', '2-26-2012', '01-07-2016', 'Senior Analyst', 27.0, 55417, 'IT', 18.0, 12.0, 2.0, 0)
# ('JARRETT', 'ALBAREZ', 'M', '11-20-2013', '01-07-2016', 'Analyst', 21.0, 41803, 'Web', 30.0, 0.0, 2.0, 0)
# ('MAVIS', 'ANKROM', 'F', '11-24-2011', '01-07-2016', 'Manager', 35.0, 113837, 'Marketing', 20.0, 10.0, 4.0, 8)
# ('NAOMI', 'AMEDEO', 'F', '7-20-2014', '01-07-2016', 'Senior Analyst', 28.0, 69851, 'Finance', 28.0, 2.0, 4.0, 3)
# ('BO', 'ALIBOZEK', 'M', '11-03-2014', '01-07-2016', 'Analyst', 23.0, 42429, 'Operations', 24.0, 6.0, 2.0, 1)
# ('PARIS', 'ALIOTTA', 'M', '9-16-2012', '01-07-2016', 'Associate', 30.0, 90346, 'Marketing', 21.0, 9.0, 3.0, 2)
# ('DEMARCUS', 'ALFORD', 'M', '12-08-2014', '01-07-2016', 'Analyst', 22.0, 44980, 'Web', 19.0, 11.0, 4.0, 0)
# ('LYMAN', 'ALDARONDO', 'M', '1-17-2012', '01-07-2016', 'Manager', 32.0, 124711, 'Finance', 17.0, 13.0, 3.0, 6)
# ('ODELL', 'AIPORLANI', 'M', '10-21-2013', '01-07-2016', 'Analyst', 21.0, 42803, 'Management', 24.0, 6.0, 2.0, 0)
# ('JUSTIN', 'ABBE', 'M', '5-28-2014', '01-07-2016', 'Analyst', 22.0, 44015, 'IT', 20.0, 10.0, 5.0, 0)
# ('THEODORA', 'ARENT', 'F', '06-09-2012', '01-07-2016', 'Senior Analyst', 28.0, 55693, 'Management', 15.0, 15.0, 2.0, 2)
# ('LURA', 'ARMENTA', 'F', '6-24-2013', '01-07-2016', 'Senior Analyst', 26.0, 52083, 'Operations', 19.0, 11.0, 4.0, 1)
# ('LYLE', 'ADAMCZYK', 'M', '6-19-2013', '01-07-2016', 'Analyst', 24.0, 46907, 'IT', 16.0, 14.0, 2.0, 0)
# ('BILLIE', 'AMEIGH', 'F', '07-12-2012', '01-07-2016', 'Senior Analyst', 26.0, 63008, 'Marketing', 28.0, 2.0, 2.0, 0)
# ('AUSTIN', 'ACORD', 'M', '11-16-2014', '01-07-2016', 'Senior Analyst', 25.0, 64112, 'Management', 19.0, 11.0, 3.0, 0)
# ('MAX', 'ACHEAMPONG', 'M', '01-11-2015', '01-07-2016', 'Analyst', 24.0, 44888, 'Operations', 29.0, 1.0, 2.0, 2)
# ('CLARICE', 'ANGRY', 'F', '11-11-2013', '01-07-2016', 'Analyst', 25.0, 41921, 'Operations', 29.0, 1.0, 5.0, 2)
# ('JULIANNE', 'ANWAR', 'F', '01-09-2014', '01-07-2016', 'Analyst', 22.0, 41926, 'IT', 18.0, 12.0, 3.0, 0)
# ('BONITA', 'ANDREASSEN', 'F', '09-02-2012', '01-07-2016', 'Director', 45.0, 324783, 'Finance', 24.0, 6.0, 5.0, 19)
# ('JANIS', 'ANASAGASTI', 'F', '12-09-2013', '01-07-2016', 'Analyst', 24.0, 46499, 'Operations', 22.0, 8.0, 3.0, 1)
# ('JOSEFINA', 'ANDERSSON', 'F', '03-07-2013', '01-07-2016', 'Analyst', 21.0, 42754, 'Marketing', 16.0, 14.0, 3.0, 0)
# ('ROMAN', 'AFFELT', 'M', '12-20-2014', '01-07-2016', 'Analyst', 22.0, 46812, 'Operations', 28.0, 2.0, 4.0, 0)
# ('ADOLPH', 'AHRENDT', 'M', '11-17-2014', '01-07-2016', 'Analyst', 22.0, 47001, 'IT', 16.0, 14.0, 4.0, 0)
# ('DIANA', 'ALTHAUS', 'F', '4-28-2014', '01-07-2016', 'Analyst', 24.0, 40646, 'Operations', 24.0, 6.0, 5.0, 1)
# ('SONJA', 'ANDERE', 'F', '07-11-2012', '01-07-2016', 'Associate', 30.0, 97879, 'Marketing', 30.0, 0.0, 2.0, 3)
# ('MONIQUE', 'AMISON', 'F', '4-19-2014', '01-07-2016', 'Analyst', 21.0, 49013, 'Marketing', 16.0, 14.0, 5.0, 0)
# ('DELMA', 'AREDONDO', 'F', '02-03-2013', '01-07-2016', 'Analyst', 23.0, 41120, 'Finance', 21.0, 9.0, 3.0, 0)
# ('AMY', 'ALOUF', 'F', '05-12-2014', '01-07-2016', 'Manager', 32.0, 126181, 'IT', 22.0, 8.0, 5.0, 5)
# ('DESTINY', 'AREIAS', 'F', '12-18-2014', '01-07-2016', 'Associate', 31.0, 76143, 'Operations', 24.0, 6.0, 3.0, 6)
# ('BUSTER', 'ALIZADEH', 'M', '5-22-2013', '01-07-2016', 'Analyst', 23.0, 40998, 'Management', 27.0, 3.0, 5.0, 0)
# ('DANNIE', 'ALEMAN', 'M', '5-17-2010', '01-07-2016', 'Senior Manager', 36.0, 198814, 'Operations', 22.0, 8.0, 5.0, 6)
# ('KRISTOPHER', 'ADKERSON', 'M', '03-09-2013', '01-07-2016', 'Analyst', 24.0, 43417, 'Finance', 27.0, 3.0, 2.0, 0)
# ('BIANCA', 'ANO', 'F', '7-31-2013', '01-07-2016', 'Senior Analyst', 27.0, 59111, 'IT', 19.0, 11.0, 3.0, 4)
# ('OWEN', 'ADIL', 'M', '4-29-2012', '01-07-2016', 'Associate', 28.0, 72328, 'Finance', 27.0, 3.0, 3.0, 0)
# ('NATHANIEL', 'ABSHIRE', 'M', '11-17-2014', '01-07-2016', 'Analyst', 23.0, 44225, 'Operations', 17.0, 13.0, 3.0, 1)
# ('MYLES', 'ALAYA', 'M', '07-05-2013', '01-07-2016', 'Analyst', 25.0, 47561, 'Marketing', 30.0, 0.0, 2.0, 1)
# ('IRENE', 'ALSTOTT', 'F', '02-06-2014', '01-07-2016', 'Analyst', 25.0, 44512, 'Marketing', 25.0, 5.0, 2.0, 2)
# ('ALEX', 'ABOLAFIA', 'M', '11-10-2013', '01-07-2016', 'Analyst', 25.0, 43352, 'Finance', 27.0, 3.0, 4.0, 2)
# ('HIPOLITO', 'ALHUSSEINI', 'M', '1-14-2015', '01-07-2016', 'Analyst', 25.0, 49619, 'Marketing', 30.0, 0.0, 2.0, 3)
# ('LILLIAN', 'ALTHEIMER', 'F', '05-03-2014', '01-07-2016', 'Analyst', 25.0, 43991, 'Management', 25.0, 5.0, 4.0, 2)
# ('GLENNA', 'ANGLADE', 'F', '04-01-2014', '01-07-2016', 'Analyst', 23.0, 44712, 'Marketing', 18.0, 12.0, 5.0, 0)
# ('ELBA', 'ARBOGAST', 'F', '12-25-2014', '01-07-2016', 'Analyst', 21.0, 47401, 'Finance', 27.0, 3.0, 2.0, 0)
# ('NICOLAS', 'ADMAS', 'M', '2-29-2012', '01-07-2016', 'Associate', 29.0, 85391, 'Web', 19.0, 11.0, 2.0, 1)
# ('VIRGINIA', 'ALPER', 'F', '01-08-2015', '01-07-2016', 'Analyst', 24.0, 47638, 'Web', 21.0, 9.0, 2.0, 2)
# ('TERRY', 'AMBORN', 'F', '08-01-2013', '01-07-2016', 'Analyst', 22.0, 41284, 'Operations', 23.0, 7.0, 4.0, 0)
# ('DONNELL', 'AIMONE', 'M', '10-20-2014', '01-07-2016', 'Analyst', 24.0, 46251, 'Finance', 28.0, 2.0, 5.0, 2)
# ('ABE', 'ALBERTO', 'M', '12-14-2014', '01-07-2016', 'Analyst', 25.0, 47183, 'IT', 23.0, 7.0, 2.0, 3)
# ('HELEN', 'ALMY', 'F', '4-26-2014', '01-07-2016', 'Analyst', 23.0, 44214, 'Web', 23.0, 7.0, 4.0, 0)
# ('CRAIG', 'ABDULLA', 'M', '10-02-2013', '01-07-2016', 'Analyst', 22.0, 41227, 'IT', 24.0, 6.0, 2.0, 0)
# ('PARKER', 'ALBURY', 'M', '12-21-2013', '01-07-2016', 'Analyst', 25.0, 43474, 'Management', 27.0, 3.0, 5.0, 2)
# ('SHANNON', 'ALTOMARI', 'F', '3-25-2014', '01-07-2016', 'Analyst', 22.0, 42178, 'Web', 28.0, 2.0, 3.0, 0)
# ('BROOKE', 'AMSLEY', 'F', '05-05-2013', '01-07-2016', 'Analyst', 23.0, 40436, 'Operations', 19.0, 11.0, 4.0, 0)
# ('OLIVER', 'ACY', 'M', '5-15-2013', '01-07-2016', 'Analyst', 22.0, 41354, 'Marketing', 26.0, 4.0, 4.0, 0)
# ('SILAS', 'AJELLO', 'M', '09-08-2013', '01-07-2016', 'Analyst', 22.0, 40417, 'Operations', 24.0, 6.0, 4.0, 0)
# ('APRIL', 'ALUAREZ', 'F', '4-18-2014', '01-07-2016', 'Analyst', 22.0, 44617, 'Management', 28.0, 2.0, 2.0, 0)
# ('RONALD', 'AARONSON', 'M', '9-16-2013', '01-07-2016', 'Analyst', 21.0, 44163, 'Finance', 18.0, 12.0, 4.0, 0)
# ('YVONNE', 'ALVES', 'F', '12-01-2013', '01-07-2016', 'Analyst', 23.0, 45123, 'Web', 29.0, 1.0, 4.0, 0)
# ('GERALD', 'ABBENANTE', 'M', '05-06-2014', '01-07-2016', 'Analyst', 22.0, 41550, 'Management', 19.0, 11.0, 5.0, 0)
# ('MILAN', 'ALLEGRA', 'M', '06-12-2013', '01-07-2016', 'Analyst', 22.0, 41989, 'IT', 18.0, 12.0, 5.0, 0)
# ('HOSEA', 'ALLMAND', 'M', '06-03-2014', '01-07-2016', 'Analyst', 24.0, 46206, 'IT', 19.0, 11.0, 2.0, 1)
# ('DOUGLAS', 'ABATTI', 'M', '08-07-2014', '01-07-2016', 'Analyst', 23.0, 42255, 'Web', 26.0, 4.0, 4.0, 1)
# ('ASHLEY', 'AGUMGA', 'M', '1-28-2014', '01-07-2016', 'Analyst', 24.0, 42667, 'Management', 19.0, 11.0, 2.0, 1)
# ('NOEL', 'ADELMUND', 'M', '05-03-2014', '01-07-2016', 'Analyst', 25.0, 41734, 'Finance', 21.0, 9.0, 5.0, 2)
# ('VIDA', 'ARGENBRIGHT', 'F', '09-11-2013', '01-07-2016', 'Analyst', 22.0, 40975, 'IT', 30.0, 0.0, 4.0, 0)
# ('MADELYN', 'APPLEGARTH', 'F', '6-19-2013', '01-07-2016', 'Analyst', 22.0, 47695, 'Operations', 21.0, 9.0, 4.0, 0)
# ('CLAIR', 'AKIN', 'M', '12-27-2013', '01-07-2016', 'Analyst', 21.0, 42786, 'Marketing', 20.0, 10.0, 5.0, 0)
# ('REBA', 'ANDRICH', 'F', '2-24-2013', '01-07-2016', 'Analyst', 22.0, 48681, 'Management', 26.0, 4.0, 3.0, 0)
# ('OLIN', 'ALDERINK', 'M', '04-02-2013', '01-07-2016', 'Analyst', 21.0, 43185, 'IT', 20.0, 10.0, 5.0, 0)
# ('CAMILLE', 'ANDO', 'F', '3-29-2013', '01-07-2016', 'Analyst', 21.0, 41577, 'Management', 16.0, 14.0, 3.0, 0)
# ('PALMER', 'ALLEMAND', 'M', '03-10-2013', '01-07-2016', 'Analyst', 24.0, 41691, 'Web', 30.0, 0.0, 2.0, 0)
# ('SEBASTIAN', 'AILSTOCK', 'M', '06-11-2013', '01-07-2016', 'Senior Analyst', 27.0, 51534, 'Operations', 30.0, 0.0, 4.0, 3)
# ('ADDIE', 'ANDREEN', 'F', '03-07-2013', '01-07-2016', 'Analyst', 24.0, 49020, 'IT', 19.0, 11.0, 4.0, 0)
# ('TROY', 'ABILEZ', 'M', '10-29-2010', '01-07-2016', 'Manager', 33.0, 120184, 'Management', 20.0, 10.0, 5.0, 7)
# ('DONG', 'ALISAUSKAS', 'M', '9-26-2012', '01-07-2016', 'Manager', 34.0, 147560, 'Management', 19.0, 11.0, 3.0, 6)
# ('BLAKE', 'ADAMSEN', 'M', '6-20-2013', '01-07-2016', 'Analyst', 24.0, 49602, 'Operations', 21.0, 9.0, 5.0, 0)
# ('BETTE', 'ANGELSON', 'F', '05-11-2013', '01-07-2016', 'Analyst', 24.0, 42538, 'Marketing', 25.0, 5.0, 5.0, 0)
# ('SANDY', 'ALBERG', 'M', '1-23-2015', '01-07-2016', 'Analyst', 22.0, 41027, 'Management', 21.0, 9.0, 2.0, 0)
# ('MICHAEL', 'ANTONOVICH', 'F', '8-30-2013', '01-07-2016', 'Analyst', 21.0, 43716, 'Management', 30.0, 0.0, 2.0, 0)
# ('ETHEL', 'ALTON', 'F', '5-17-2012', '01-07-2016', 'Senior Analyst', 27.0, 60085, 'Web', 17.0, 13.0, 4.0, 0)
# ('RON', 'ABUSUFAIT', 'M', '01-01-2013', '01-07-2016', 'Analyst', 21.0, 48682, 'Web', 25.0, 5.0, 2.0, 0)
# ('TERRIE', 'ANSPACH', 'F', '6-18-2014', '01-07-2016', 'Analyst', 22.0, 42710, 'IT', 20.0, 10.0, 3.0, 0)
# ('RODRICK', 'ALBRIGHT', 'M', '10-09-2012', '01-07-2016', 'Senior Analyst', 26.0, 53390, 'Marketing', 20.0, 10.0, 5.0, 2)
# ('JOEL', 'ABIDE', 'M', '07-09-2011', '01-07-2016', 'Associate', 32.0, 99130, 'Web', 17.0, 13.0, 4.0, 3)
# ('DOUG', 'ADALJA', 'M', '07-12-2013', '01-07-2016', 'Analyst', 23.0, 45152, 'Web', 15.0, 15.0, 4.0, 0)
# ('JAY', 'ABNER', 'M', '01-06-2013', '01-07-2016', 'Analyst', 21.0, 43357, 'Web', 28.0, 2.0, 3.0, 0)
# ('LYNETTE', 'ANASTASIADES', 'F', '08-01-2012', '01-07-2016', 'Senior Analyst', 26.0, 57000, 'Marketing', 27.0, 3.0, 5.0, 0)
# ('DARIUS', 'AHL', 'M', '08-05-2014', '01-07-2016', 'Analyst', 21.0, 44134, 'Marketing', 30.0, 0.0, 2.0, 0)
# ('IRVING', 'ADIB', 'M', '9-19-2014', '01-07-2016', 'Analyst', 23.0, 44148, 'Finance', 25.0, 5.0, 3.0, 1)
# ('ROB', 'AHHEE', 'M', '06-03-2012', '01-07-2016', 'Senior Analyst', 25.0, 56181, 'Management', 15.0, 15.0, 2.0, 0)
# ('CANDACE', 'AMMIRATA', 'F', '11-24-2014', '01-07-2016', 'Analyst', 23.0, 48287, 'Finance', 19.0, 11.0, 2.0, 1)
# ('DWAYNE', 'ACHEE', 'M', '10-11-2014', '01-07-2016', 'Senior Analyst', 25.0, 69421, 'Finance', 25.0, 5.0, 4.0, 3)
# ('ARLIE', 'ALLWARDT', 'M', '4-25-2014', '01-07-2016', 'Analyst', 23.0, 44342, 'Operations', 26.0, 4.0, 5.0, 0)
# ('OPAL', 'AMMON', 'F', '1-16-2014', '01-07-2016', 'Senior Analyst', 28.0, 61710, 'Management', 15.0, 15.0, 4.0, 2)
# ('JUAN', 'ABBASSI', 'M', '07-01-2013', '01-07-2016', 'Senior Analyst', 27.0, 61575, 'Finance', 20.0, 10.0, 2.0, 1)
# ('COLUMBUS', 'ALGEO', 'M', '3-18-2013', '01-07-2016', 'Analyst', 22.0, 46038, 'IT', 16.0, 14.0, 3.0, 0)
# ('NICHOLAS', 'ABBOTT', 'M', '04-06-2014', '01-07-2016', 'Associate', 31.0, 78493, 'IT', 21.0, 9.0, 2.0, 4)
# ('MONIKA', 'ARCHBELL', 'F', '10-07-2014', '01-07-2016', 'Analyst', 25.0, 43292, 'Operations', 26.0, 4.0, 4.0, 3)
# ('HANS', 'AGUADA', 'M', '4-14-2014', '01-07-2016', 'Analyst', 25.0, 42657, 'Operations', 27.0, 3.0, 3.0, 2)
# ('TAYLOR', 'ADLEMAN', 'M', '3-19-2013', '01-07-2016', 'Analyst', 25.0, 42400, 'Operations', 29.0, 1.0, 3.0, 1)
# ('AURELIA', 'APPLETON', 'F', '2-25-2013', '01-07-2016', 'Analyst', 24.0, 41713, 'Marketing', 16.0, 14.0, 3.0, 0)
# ('GREGORIO', 'AGUNDEZ', 'M', '2-20-2013', '01-07-2016', 'Analyst', 21.0, 46664, 'Finance', 21.0, 9.0, 3.0, 0)
# ('TANIA', 'ANTON', 'F', '8-19-2013', '01-07-2016', 'Senior Analyst', 26.0, 66339, 'Management', 24.0, 6.0, 5.0, 1)
# ('FREDDIE', 'ARESCO', 'F', '1-28-2014', '01-07-2016', 'Analyst', 22.0, 45450, 'IT', 27.0, 3.0, 2.0, 0)
# ('HORTENCIA', 'ARENSTAM', 'F', '6-13-2014', '01-07-2016', 'Analyst', 25.0, 43355, 'Web', 22.0, 8.0, 3.0, 2)
# ('BRITTANY', 'ALVIZO', 'F', '05-10-2013', '01-07-2016', 'Analyst', 23.0, 42140, 'Operations', 29.0, 1.0, 4.0, 0)
# ('AVERY', 'AHONEN', 'M', '08-03-2014', '01-07-2016', 'Senior Analyst', 28.0, 52406, 'Operations', 19.0, 11.0, 2.0, 5)
# ('MATHEW', 'ACERET', 'M', '09-12-2014', '01-07-2016', 'Analyst', 24.0, 42440, 'IT', 20.0, 10.0, 4.0, 2)
# ('RICH', 'ALBANG', 'M', '01-02-2012', '01-07-2016', 'Senior Analyst', 25.0, 64913, 'Finance', 29.0, 1.0, 4.0, 0)
# ('LUPE', 'ANGELOS', 'F', '1-17-2013', '01-07-2016', 'Analyst', 21.0, 41551, 'Operations', 21.0, 9.0, 2.0, 0)
# ('AGUSTIN', 'AGUDO', 'M', '5-27-2013', '01-07-2016', 'Senior Analyst', 26.0, 54689, 'Management', 23.0, 7.0, 5.0, 0)
# ('MYRA', 'AMR', 'F', '4-28-2014', '01-07-2016', 'Analyst', 22.0, 48747, 'Operations', 21.0, 9.0, 4.0, 0)
# ('GEORGINA', 'ANSARI', 'F', '9-24-2014', '01-07-2016', 'Senior Analyst', 25.0, 59907, 'IT', 17.0, 13.0, 5.0, 0)
# ('KIM', 'ADERSON', 'M', '12-20-2013', '01-07-2016', 'Analyst', 25.0, 45319, 'Management', 16.0, 14.0, 2.0, 2)
# ('HAI', 'ALMEN', 'M', '6-29-2012', '01-07-2016', 'Senior Analyst', 28.0, 60707, 'Finance', 26.0, 4.0, 3.0, 2)
# ('TRACY', 'ALTIG', 'F', '4-24-2014', '01-07-2016', 'Analyst', 24.0, 43124, 'IT', 19.0, 11.0, 4.0, 1)
# ('JODIE', 'ANIELLO', 'F', '10-29-2014', '01-07-2016', 'Analyst', 24.0, 43137, 'IT', 27.0, 3.0, 2.0, 2)
# ('ALEXIS', 'AHRENDS', 'M', '10-21-2013', '01-07-2016', 'Analyst', 22.0, 42121, 'Finance', 30.0, 0.0, 5.0, 0)
# ('WENDY', 'ALTMILLER', 'F', '9-27-2014', '01-07-2016', 'Analyst', 24.0, 45950, 'Marketing', 15.0, 15.0, 3.0, 2)
# ('SELINA', 'ARDELEAN', 'F', '02-10-2013', '01-07-2016', 'Senior Analyst', 25.0, 55525, 'Operations', 18.0, 12.0, 2.0, 0)
# ('ROBBY', 'ALAIBILLA', 'M', '10-28-2010', '01-07-2016', 'Manager', 34.0, 112580, 'Management', 30.0, 0.0, 5.0, 8)
# ('ERNESTINA', 'AREAS', 'F', '5-24-2014', '01-07-2016', 'Analyst', 23.0, 42160, 'Finance', 20.0, 10.0, 3.0, 0)
# ('ALICE', 'ALRAIS', 'F', '07-07-2014', '01-07-2016', 'Analyst', 22.0, 40335, 'Finance', 27.0, 3.0, 3.0, 0)
# ('ALLYSON', 'ANTOLINI', 'F', '2-28-2014', '01-07-2016', 'Analyst', 21.0, 40363, 'IT', 27.0, 3.0, 5.0, 0)
# ('VERNELL', 'ARMELIN', 'F', '4-15-2013', '01-07-2016', 'Analyst', 24.0, 49029, 'Marketing', 23.0, 7.0, 2.0, 0)
# ('ELAINE', 'ALTOP', 'F', '11-01-2013', '01-07-2016', 'Analyst', 24.0, 48775, 'Operations', 22.0, 8.0, 5.0, 1)
# ('MARLON', 'AGBISIT', 'M', '03-02-2014', '01-07-2016', 'Analyst', 21.0, 40396, 'Marketing', 28.0, 2.0, 2.0, 0)
# ('KELLY', 'ALSMAN', 'F', '11-14-2014', '01-07-2016', 'Analyst', 25.0, 45998, 'Finance', 18.0, 12.0, 5.0, 3)
# ...
# ('BRYON', 'AHLGREN', 'M', '11-21-2013', '01-07-2016', 'Analyst', 22.0, 49878, 'Marketing', 24.0, 6.0, 5.0, 0)
# ('MERLE', 'APARICIO', 'F', '07-09-2013', '01-07-2016', 'Analyst', 22.0, 45147, 'Marketing', 30.0, 0.0, 2.0, 0)
# ('TAMEKA', 'ANTONETTI', 'F', '6-27-2013', '01-07-2016', 'Analyst', 23.0, 45645, 'Web', 15.0, 15.0, 3.0, 0)
# ('CLEVELAND', 'AGREDANO', 'M', '11-27-2013', '01-07-2016', 'Analyst', 25.0, 46064, 'IT', 18.0, 12.0, 3.0, 2)
# ('DORA', 'AMBLE', 'F', '03-03-2014', '01-07-2016', 'Analyst', 23.0, 43288, 'Operations', 27.0, 3.0, 5.0, 0)
# ('ELLIE', 'ARLINE', 'F', '12-07-2013', '01-07-2016', 'Analyst', 22.0, 40208, 'Operations', 17.0, 13.0, 3.0, 0)
# ('MAURO', 'ALEKSEY', 'M', '12-30-2014', '01-07-2016', 'Analyst', 25.0, 42070, 'Management', 23.0, 7.0, 2.0, 3)
# ('ALBERT', 'ABBATIELLO', 'M', '05-06-2014', '01-07-2016', 'Analyst', 22.0, 49577, 'Web', 19.0, 11.0, 4.0, 0)
# ('REX', 'ADAMI', 'M', '5-24-2012', '01-07-2016', 'Senior Analyst', 27.0, 56112, 'Management', 18.0, 12.0, 5.0, 0)
# ('MINH', 'ALFONSI', 'M', '8-21-2013', '01-07-2016', 'Analyst', 24.0, 46762, 'Marketing', 19.0, 11.0, 2.0, 1)
# ('KIRA', 'ARIOLA', 'F', '3-21-2014', '01-07-2016', 'Analyst', 21.0, 44323, 'Operations', 20.0, 10.0, 2.0, 0)
# ('JAE', 'ALLGAEUER', 'M', '01-04-2012', '01-07-2016', 'Senior Manager', 37.0, 153769, 'Marketing', 19.0, 11.0, 3.0, 8)
# ('TIM', 'ABRAHAMS', 'M', '11-22-2013', '01-07-2016', 'Analyst', 21.0, 40762, 'IT', 30.0, 0.0, 4.0, 0)
# ('DELILAH', 'ARENOS', 'F', '09-09-2014', '01-07-2016', 'Analyst', 24.0, 49567, 'Operations', 21.0, 9.0, 4.0, 2)
# ('SUSANA', 'ANGELUCCI', 'F', '05-09-2014', '01-07-2016', 'Senior Analyst', 28.0, 65810, 'Finance', 21.0, 9.0, 2.0, 5)
# ('LATRICE', 'ARENDASH', 'F', '2-16-2012', '01-07-2016', 'Associate', 30.0, 99311, 'Finance', 25.0, 5.0, 4.0, 5)
# ('SARAH', 'ALOIA', 'F', '10-30-2013', '01-07-2016', 'Analyst', 23.0, 43495, 'Finance', 26.0, 4.0, 2.0, 0)
# ('SOLEDAD', 'ARGUE', 'F', '8-22-2013', '01-07-2016', 'Analyst', 25.0, 40073, 'IT', 15.0, 15.0, 5.0, 2)
# ('LUKE', 'ADA', 'M', '08-05-2013', '01-07-2016', 'Analyst', 21.0, 49380, 'Management', 30.0, 0.0, 4.0, 0)
# ('VICENTE', 'AGIN', 'M', '8-15-2012', '01-07-2016', 'Senior Analyst', 26.0, 64480, 'Finance', 30.0, 0.0, 5.0, 2)
# ('STEFAN', 'AITKINS', 'M', '10-01-2013', '01-07-2016', 'Analyst', 22.0, 49549, 'Finance', 23.0, 7.0, 5.0, 0)
# ('LESTER', 'ABRIAL', 'M', '8-19-2013', '01-07-2016', 'Analyst', 24.0, 46369, 'Management', 28.0, 2.0, 3.0, 1)
# ('IMOGENE', 'ANGIOLILLO', 'F', '12-31-2014', '01-07-2016', 'Analyst', 25.0, 46488, 'IT', 15.0, 15.0, 2.0, 3)
# ('ANDRE', 'ABUHL', 'M', '8-28-2014', '01-07-2016', 'Analyst', 23.0, 49101, 'Marketing', 20.0, 10.0, 5.0, 1)
# ('RASHAD', 'ALIM', 'M', '12-29-2014', '01-07-2016', 'Analyst', 23.0, 41895, 'Operations', 20.0, 10.0, 5.0, 1)
# ('HORACE', 'ADAMSKY', 'M', '5-31-2014', '01-07-2016', 'Analyst', 25.0, 40786, 'IT', 25.0, 5.0, 5.0, 2)
# ('LASHAWN', 'ARIDAS', 'F', '7-26-2014', '01-07-2016', 'Analyst', 25.0, 48957, 'Web', 23.0, 7.0, 3.0, 3)
# ('LUPE', 'ALESNA', 'M', '1-29-2014', '01-07-2016', 'Analyst', 21.0, 49271, 'Management', 28.0, 2.0, 4.0, 0)
# ('WILBURN', 'ALATTAR', 'M', '07-05-2011', '01-07-2016', 'Manager', 34.0, 139380, 'Marketing', 29.0, 1.0, 2.0, 4)
# ('ALLAN', 'ACEVES', 'M', '04-09-2013', '01-07-2016', 'Senior Manager', 38.0, 189435, 'Marketing', 19.0, 11.0, 4.0, 10)
# ('EARNESTINE', 'ANTONY', 'F', '9-19-2012', '01-07-2016', 'Senior Analyst', 26.0, 66244, 'Operations', 27.0, 3.0, 4.0, 0)
# ('ZELDA', 'ARCINIEGA', 'F', '05-06-2014', '01-07-2016', 'Analyst', 25.0, 47229, 'Marketing', 17.0, 13.0, 5.0, 2)
# ('EVERETTE', 'ALBORNOZ', 'M', '8-17-2014', '01-07-2016', 'Analyst', 25.0, 47747, 'Operations', 22.0, 8.0, 5.0, 3)
# ('FLOYD', 'ABRACHINSKY', 'M', '4-19-2014', '01-07-2016', 'Analyst', 23.0, 47348, 'Operations', 19.0, 11.0, 4.0, 0)
# ('SOLOMON', 'AGYEMAN', 'M', '9-28-2013', '01-07-2016', 'Analyst', 22.0, 44163, 'Management', 16.0, 14.0, 2.0, 0)
# ('MARGIE', 'AMBUEHL', 'F', '08-09-2013', '01-07-2016', 'Associate', 32.0, 78556, 'Marketing', 16.0, 14.0, 3.0, 5)
# ('VILMA', 'APRIGLIANO', 'F', '1-18-2014', '01-07-2016', 'Analyst', 23.0, 46984, 'Web', 24.0, 6.0, 4.0, 0)
# ('LEROY', 'ABLANG', 'M', '08-06-2013', '01-07-2016', 'Analyst', 25.0, 45435, 'Operations', 24.0, 6.0, 5.0, 2)
# ('WADE', 'ACOR', 'M', '06-12-2013', '01-07-2016', 'Senior Analyst', 26.0, 54987, 'Marketing', 25.0, 5.0, 3.0, 1)
# ('AURELIO', 'AKEMON', 'M', '05-08-2013', '01-07-2016', 'Analyst', 21.0, 47301, 'Web', 24.0, 6.0, 4.0, 0)
# ('CASEY', 'ANDAYA', 'F', '5-23-2014', '01-07-2016', 'Analyst', 24.0, 42428, 'Management', 15.0, 15.0, 3.0, 1)
# ('ELMER', 'ABUNDIS', 'M', '06-11-2014', '01-07-2016', 'Analyst', 24.0, 49654, 'Finance', 27.0, 3.0, 4.0, 1)
# ('FAUSTO', 'ALLESSI', 'M', '2-20-2013', '01-07-2016', 'Analyst', 24.0, 42266, 'Management', 20.0, 10.0, 5.0, 0)
# ('CRISTOBAL', 'ALLBRIGHT', 'M', '9-28-2013', '01-07-2016', 'Analyst', 21.0, 47781, 'IT', 17.0, 13.0, 3.0, 0)
# ('AUGUSTUS', 'ALEIZAR', 'M', '1-24-2012', '01-07-2016', 'Associate', 29.0, 70823, 'Web', 26.0, 4.0, 5.0, 0)
# ('EMMETT', 'AGBAYANI', 'M', '3-16-2012', '01-07-2016', 'Senior Analyst', 26.0, 58638, 'Marketing', 25.0, 5.0, 2.0, 1)
# ('EDMUNDO', 'ALMAJHOUB', 'M', '01-12-2014', '01-07-2016', 'Analyst', 22.0, 48266, 'IT', 21.0, 9.0, 3.0, 0)
# ('MARSHALL', 'ACKISON', 'M', '04-04-2014', '01-07-2016', 'Analyst', 24.0, 45776, 'Management', 17.0, 13.0, 4.0, 1)
# ('CECILE', 'ANGERER', 'F', '5-25-2013', '01-07-2016', 'Senior Analyst', 28.0, 69841, 'Management', 21.0, 9.0, 5.0, 0)
# ('CARMELLA', 'ANTOS', 'F', '08-08-2014', '01-07-2016', 'Director', 39.0, 368887, 'Management', 21.0, 9.0, 3.0, 13)
# ('OTHA', 'ALIPIO', 'M', '8-31-2014', '01-07-2016', 'Analyst', 23.0, 41454, 'Finance', 25.0, 5.0, 4.0, 1)
# ('JEANIE', 'ANTISTA', 'F', '7-26-2014', '01-07-2016', 'Analyst', 21.0, 49799, 'Web', 15.0, 15.0, 2.0, 0)
# ('ADELAIDE', 'ARCHIBOLD', 'F', '11-11-2010', '01-07-2016', 'Director', 39.0, 213987, 'Web', 24.0, 6.0, 5.0, 13)
# ('CONSUELO', 'ANGAROLA', 'F', '07-09-2011', '01-07-2016', 'Associate', 32.0, 95768, 'Web', 15.0, 15.0, 5.0, 2)
# ('MONTY', 'AHMADI', 'M', '8-24-2013', '01-07-2016', 'Analyst', 25.0, 47993, 'Marketing', 26.0, 4.0, 5.0, 2)
# ('ROOSEVELT', 'ADES', 'M', '02-12-2014', '01-07-2016', 'Analyst', 24.0, 45100, 'Operations', 28.0, 2.0, 2.0, 1)
# ('MATTHEW', 'AASE', 'M', '6-19-2013', '01-07-2016', 'Analyst', 23.0, 45797, 'Marketing', 17.0, 13.0, 3.0, 0)
# ('GUY', 'ACFALLE', 'M', '9-18-2013', '01-07-2016', 'Analyst', 22.0, 46098, 'Operations', 21.0, 9.0, 4.0, 0)
# ('CARSON', 'AKUNA', 'M', '12-16-2014', '01-07-2016', 'Analyst', 21.0, 41854, 'Operations', 29.0, 1.0, 5.0, 0)
# ('CHONG', 'ALINE', 'M', '11-15-2014', '01-07-2016', 'Analyst', 21.0, 41250, 'IT', 23.0, 7.0, 5.0, 0)
# ('JEROLD', 'ALCOSIBA', 'M', '07-04-2014', '01-07-2016', 'Manager', 34.0, 108931, 'Operations', 22.0, 8.0, 5.0, 10)
# ('JEWELL', 'ANGELI', 'F', '3-27-2012', '01-07-2016', 'Manager', 32.0, 112363, 'Finance', 18.0, 12.0, 3.0, 7)
# ('MANUELA', 'ANNARUMMO', 'F', '5-29-2014', '01-07-2016', 'Analyst', 23.0, 41037, 'Management', 24.0, 6.0, 3.0, 0)
# ('WILLIAN', 'ALMARIO', 'M', '1-26-2015', '01-07-2016', 'Analyst', 25.0, 49730, 'Marketing', 26.0, 4.0, 5.0, 3)
# ('ASHLEY', 'ALSHOUSE', 'F', '06-04-2014', '01-07-2016', 'Associate', 28.0, 88281, 'Marketing', 28.0, 2.0, 4.0, 2)
# ('DOLLY', 'ANNE', 'F', '04-09-2014', '01-07-2016', 'Analyst', 21.0, 49725, 'Finance', 25.0, 5.0, 4.0, 0)
# ('MAURICIO', 'AIKEN', 'M', '7-13-2014', '01-07-2016', 'Senior Analyst', 27.0, 69877, 'Management', 27.0, 3.0, 2.0, 5)
# ('LATONYA', 'ANFINSON', 'F', '12-23-2012', '01-07-2016', 'Manager', 32.0, 139804, 'Marketing', 21.0, 9.0, 4.0, 7)
# ('JARVIS', 'AIRD', 'M', '9-22-2014', '01-07-2016', 'Analyst', 24.0, 41531, 'Management', 19.0, 11.0, 3.0, 2)
# ('RHONDA', 'ALTVATER', 'F', '10-07-2014', '01-07-2016', 'Analyst', 23.0, 45082, 'Operations', 17.0, 13.0, 2.0, 1)
# ('LOU', 'ALGEE', 'M', '04-08-2013', '01-07-2016', 'Analyst', 23.0, 49904, 'Management', 28.0, 2.0, 4.0, 0)
# ('CECELIA', 'ANCELET', 'F', '01-08-2013', '01-07-2016', 'Analyst', 23.0, 43905, 'IT', 24.0, 6.0, 5.0, 0)
# ('CARRIE', 'ALTRINGER', 'F', '10-02-2013', '01-07-2016', 'Analyst', 22.0, 40357, 'Marketing', 27.0, 3.0, 2.0, 0)
# ('CHARMAINE', 'AOAY', 'F', '7-22-2013', '01-07-2016', 'Analyst', 25.0, 41147, 'Finance', 19.0, 11.0, 3.0, 2)
# ('ENOCH', 'ALFERA', 'M', '6-13-2013', '01-07-2016', 'Analyst', 23.0, 40086, 'Marketing', 25.0, 5.0, 4.0, 0)
# ('PEARLIE', 'ANTONE', 'F', '7-31-2014', '01-07-2016', 'Analyst', 25.0, 49734, 'Management', 18.0, 12.0, 3.0, 3)
# ('OLA', 'ANGELONE', 'F', '04-12-2013', '01-07-2016', 'Senior Analyst', 27.0, 51277, 'Operations', 24.0, 6.0, 5.0, 2)
# ('DAMIAN', 'AGRESTE', 'M', '11-02-2013', '01-07-2016', 'Analyst', 24.0, 40065, 'IT', 24.0, 6.0, 2.0, 1)
# ('EDWINA', 'ANZAI', 'F', '08-06-2013', '01-07-2016', 'Analyst', 24.0, 40707, 'Web', 21.0, 9.0, 4.0, 1)
# ('ART', 'AIU', 'M', '4-13-2014', '01-07-2016', 'Analyst', 23.0, 49913, 'Operations', 27.0, 3.0, 3.0, 0)
# ('MELISA', 'ANTILLON', 'F', '11-22-2013', '01-07-2016', 'Analyst', 23.0, 43534, 'Finance', 20.0, 10.0, 4.0, 0)
# ('SABRINA', 'AMEZQUITA', 'F', '7-23-2012', '01-07-2016', 'Senior Manager', 36.0, 195985, 'Finance', 26.0, 4.0, 4.0, 10)
# ('ROMEO', 'AINSLEY', 'M', '11-20-2014', '01-07-2016', 'Analyst', 23.0, 41052, 'IT', 15.0, 15.0, 5.0, 1)
# ('MARI', 'APODOCA', 'F', '02-03-2014', '01-07-2016', 'Analyst', 21.0, 40720, 'Web', 15.0, 15.0, 4.0, 0)
# ('ATHENA', 'ARGUETA', 'F', '9-27-2013', '01-07-2016', 'Analyst', 21.0, 45351, 'Finance', 15.0, 15.0, 2.0, 0)
# ('PERCY', 'AERY', 'M', '11-20-2011', '01-07-2016', 'Associate', 32.0, 77218, 'Finance', 25.0, 5.0, 3.0, 6)
# ('GILBERT', 'ABRUZZESE', 'M', '7-21-2014', '01-07-2016', 'Analyst', 21.0, 40882, 'Finance', 16.0, 14.0, 5.0, 0)
# ('KARIN', 'ANDRSON', 'F', '06-08-2013', '01-07-2016', 'Analyst', 25.0, 44318, 'Operations', 25.0, 5.0, 2.0, 1)
# ('GRETA', 'ANSLINGER', 'F', '5-18-2013', '01-07-2016', 'Associate', 30.0, 96322, 'Web', 24.0, 6.0, 2.0, 5)
# ('BARRY', 'ABINGTON', 'M', '06-09-2014', '01-07-2016', 'Analyst', 23.0, 49322, 'Web', 23.0, 7.0, 4.0, 0)
# ('KRISTAL', 'ARMOLD', 'F', '01-05-2013', '01-07-2016', 'Senior Manager', 38.0, 187837, 'Web', 19.0, 11.0, 2.0, 11)
# ('DEE', 'ANNETTE', 'F', '8-27-2013', '01-07-2016', 'Senior Analyst', 28.0, 51566, 'Web', 16.0, 14.0, 4.0, 2)
# ('LINDSEY', 'AMERO', 'F', '7-31-2014', '01-07-2016', 'Analyst', 22.0, 43418, 'Finance', 29.0, 1.0, 4.0, 0)
# ('HUGO', 'ADOLPHUS', 'M', '1-22-2014', '01-07-2016', 'Senior Analyst', 28.0, 68079, 'Management', 21.0, 9.0, 5.0, 2)
# ('LAMAR', 'AEMMER', 'M', '01-08-2013', '01-07-2016', 'Analyst', 21.0, 44146, 'Operations', 19.0, 11.0, 5.0, 0)
# ('TREVOR', 'ACUNA', 'M', '11-11-2014', '01-07-2016', 'Analyst', 22.0, 40343, 'Management', 15.0, 15.0, 2.0, 0)
# ('KELLEY', 'ANCIC', 'F', '9-26-2013', '01-07-2016', 'Analyst', 22.0, 45358, 'Marketing', 19.0, 11.0, 5.0, 0)
# ('ROYCE', 'AGOSTO', 'M', '06-07-2014', '01-07-2016', 'Analyst', 24.0, 48651, 'Web', 27.0, 3.0, 5.0, 1)
# ('HANK', 'ALEXAKI', 'M', '3-13-2012', '01-07-2016', 'Senior Analyst', 25.0, 61235, 'Management', 24.0, 6.0, 3.0, 0)
# ('CASSIE', 'ANES', 'F', '1-17-2015', '01-07-2016', 'Analyst', 22.0, 40319, 'Operations', 16.0, 14.0, 4.0, 0)
# ('DANILO', 'ALLARD', 'M', '08-02-2013', '01-07-2016', 'Analyst', 23.0, 47558, 'Marketing', 26.0, 4.0, 5.0, 0)
# ('JAMIE', 'ALUMMOOTTIL', 'F', '09-11-2010', '01-07-2016', 'Senior Manager', 38.0, 194701, 'Management', 26.0, 4.0, 5.0, 8)
# ('JESUS', 'ABETA', 'M', '12-25-2013', '01-07-2016', 'Analyst', 23.0, 45680, 'Operations', 22.0, 8.0, 3.0, 0)
# ('REGINA', 'ALVEREST', 'F', '1-26-2015', '01-07-2016', 'Analyst', 24.0, 43984, 'Marketing', 29.0, 1.0, 5.0, 2)
# ('GARFIELD', 'ALICUBEN', 'M', '11-20-2013', '01-07-2016', 'Analyst', 24.0, 40800, 'Finance', 16.0, 14.0, 2.0, 1)
# ('TYSON', 'AGUILAR', 'M', '6-20-2014', '01-07-2016', 'Analyst', 22.0, 46310, 'IT', 28.0, 2.0, 4.0, 0)
# ('SHEREE', 'APPEL', 'F', '9-24-2013', '01-07-2016', 'Analyst', 25.0, 49559, 'Management', 22.0, 8.0, 5.0, 2)
# ('KELSEY', 'ANDRZEJEWSKI', 'F', '1-23-2013', '01-07-2016', 'Analyst', 24.0, 44054, 'Web', 27.0, 3.0, 5.0, 0)
# ('CLARK', 'ADI', 'M', '11-29-2014', '01-07-2016', 'Analyst', 22.0, 41222, 'IT', 30.0, 0.0, 2.0, 0)
# ('ALPHONSE', 'ALBANY', 'M', '2-20-2012', '01-07-2016', 'Senior Manager', 38.0, 154120, 'Management', 26.0, 4.0, 3.0, 12)
# ('ALTHEA', 'ANTONICH', 'F', '4-23-2013', '01-07-2016', 'Analyst', 23.0, 42250, 'Operations', 21.0, 9.0, 2.0, 0)
# ('KYLIE', 'ARMAND', 'F', '8-20-2014', '01-07-2016', 'Analyst', 24.0, 49075, 'IT', 17.0, 13.0, 3.0, 2)
# ('TERRANCE', 'ACKROYD', 'M', '09-11-2014', '01-07-2016', 'Analyst', 24.0, 49217, 'Operations', 24.0, 6.0, 4.0, 2)
# ('SHERRY', 'ALTOBELLI', 'F', '09-05-2014', '01-07-2016', 'Senior Analyst', 26.0, 56733, 'Finance', 28.0, 2.0, 3.0, 4)
# ('LONA', 'ARGRAVE', 'F', '11-02-2012', '01-07-2016', 'Associate', 32.0, 86705, 'Operations', 20.0, 10.0, 4.0, 8)
# ('ANTONIO', 'ABEDI', 'M', '6-18-2014', '01-07-2016', 'Analyst', 22.0, 43228, 'Management', 25.0, 5.0, 4.0, 0)
# ('LESSIE', 'APPLONIE', 'F', '06-09-2013', '01-07-2016', 'Senior Analyst', 25.0, 52370, 'Operations', 24.0, 6.0, 5.0, 0)
# ('GERRY', 'AHSAN', 'M', '7-14-2011', '01-07-2016', 'Associate', 32.0, 94345, 'Management', 17.0, 13.0, 4.0, 5)
# ('MAMIE', 'AMODT', 'F', '5-29-2013', '01-07-2016', 'Analyst', 21.0, 46432, 'Operations', 30.0, 0.0, 4.0, 0)
# ('DINAH', 'ARHELGER', 'F', '09-01-2013', '01-07-2016', 'Analyst', 24.0, 44599, 'IT', 22.0, 8.0, 2.0, 1)
# ('KELLIE', 'ANDERBERG', 'F', '2-20-2014', '01-07-2016', 'Analyst', 22.0, 42418, 'Marketing', 20.0, 10.0, 3.0, 0)
# ('LINA', 'APE', 'F', '03-07-2014', '01-07-2016', 'Analyst', 21.0, 41498, 'Web', 21.0, 9.0, 5.0, 0)
# ('WINIFRED', 'ANDRADO', 'F', '4-27-2013', '01-07-2016', 'Analyst', 22.0, 41515, 'Finance', 25.0, 5.0, 5.0, 0)
# ('JEANNA', 'ARENIVAS', 'F', '9-28-2013', '01-07-2016', 'Analyst', 25.0, 48541, 'Operations', 24.0, 6.0, 2.0, 2)
# ('HATTIE', 'AMICO', 'F', '08-12-2013', '01-07-2016', 'Senior Analyst', 26.0, 66661, 'Finance', 30.0, 0.0, 5.0, 2)
# ('KENDRA', 'AMSTRONG', 'F', '5-26-2013', '01-07-2016', 'Analyst', 22.0, 44676, 'Operations', 15.0, 15.0, 3.0, 0)
# ('MOLLY', 'AMIDEI', 'F', '11-28-2013', '01-07-2016', 'Analyst', 21.0, 41378, 'Finance', 21.0, 9.0, 5.0, 0)
# ('PATRICIA', 'ALMETER', 'F', '03-01-2014', '01-07-2016', 'Analyst', 22.0, 42369, 'IT', 18.0, 12.0, 4.0, 0)
# ('AUDRA', 'ANNON', 'F', '02-06-2014', '01-07-2016', 'Analyst', 22.0, 42662, 'Finance', 29.0, 1.0, 3.0, 0)
# ('JC', 'ALKEMA', 'M', '4-15-2013', '01-07-2016', 'Analyst', 22.0, 41760, 'Finance', 21.0, 9.0, 2.0, 0)
# ('JOSPEH', 'ALLIS', 'M', '2-26-2014', '01-07-2016', 'Analyst', 22.0, 45364, 'Web', 20.0, 10.0, 2.0, 0)
# ('FRANCES', 'ALQUESTA', 'F', '5-17-2013', '01-07-2016', 'Analyst', 21.0, 49892, 'Finance', 28.0, 2.0, 4.0, 0)
# ('LEE', 'ABERLE', 'M', '12-15-2013', '01-07-2016', 'Analyst', 22.0, 49617, 'Marketing', 16.0, 14.0, 5.0, 0)
# ('ROBYN', 'AMSDELL', 'F', '10-01-2014', '01-07-2016', 'Analyst', 23.0, 42877, 'Operations', 21.0, 9.0, 2.0, 1)
# ('DREW', 'ADOLF', 'M', '12-01-2013', '01-07-2016', 'Analyst', 21.0, 48866, 'Finance', 20.0, 10.0, 3.0, 0)
# ('RICKIE', 'AICHELE', 'M', '9-28-2013', '01-07-2016', 'Analyst', 25.0, 47849, 'IT', 22.0, 8.0, 2.0, 2)
# ('ELVIA', 'APPELGREN', 'F', '5-18-2013', '01-07-2016', 'Analyst', 24.0, 44424, 'IT', 25.0, 5.0, 2.0, 0)
# ('BILLY', 'ABDELAZIZ', 'M', '06-06-2013', '01-07-2016', 'Analyst', 25.0, 43884, 'Finance', 23.0, 7.0, 4.0, 1)
# ('MARLENE', 'AMAYA', 'F', '9-15-2014', '01-07-2016', 'Analyst', 22.0, 43835, 'Management', 26.0, 4.0, 4.0, 0)
# ('ALENE', 'ARILDSEN', 'F', '8-20-2014', '01-07-2016', 'Analyst', 24.0, 40277, 'Web', 17.0, 13.0, 4.0, 2)
# ('KATHERINE', 'ALSDON', 'F', '6-28-2011', '01-07-2016', 'Senior Manager', 36.0, 185977, 'Management', 15.0, 15.0, 5.0, 10)
# ('LOUISE', 'ALTARAS', 'F', '1-14-2014', '01-07-2016', 'Analyst', 23.0, 45758, 'IT', 17.0, 13.0, 2.0, 0)
# ('RENEE', 'ALVINO', 'F', '1-23-2014', '01-07-2016', 'Analyst', 21.0, 47315, 'Web', 29.0, 1.0, 5.0, 0)
# ('TERI', 'ANASTASIO', 'F', '3-17-2014', '01-07-2016', 'Analyst', 24.0, 45172, 'Web', 23.0, 7.0, 3.0, 1)
# ('GREGORY', 'ABARCA', 'M', '9-18-2014', '01-07-2016', 'Analyst', 24.0, 49176, 'Marketing', 17.0, 13.0, 2.0, 2)
# 2025-01-16 16:11:01,022 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
### query SQL com Pandas
with engine.connect() as conn:
    query = "SELECT * FROM funcionarios;"
    
    df = pd.read_sql_query(query, con=conn)

display(df)
# Out:
# 2025-01-16 16:11:03,008 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-16 16:11:03,010 INFO sqlalchemy.engine.Engine SELECT * FROM funcionarios;
# 2025-01-16 16:11:03,011 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-01-16 16:11:03,040 INFO sqlalchemy.engine.Engine ROLLBACK
#      FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION  \
# 0        TOMASA       ARMEN   F   5-18-2014   01-07-2016         Analyst
# 1         ANNIE        None   F        None   01-07-2016       Associate
# 2         OLIVE        ANCY   F   7-28-2014   01-07-2016         Analyst
# 3        CHERRY     AQUILAR   F  04-03-2013   01-07-2016         Analyst
# 4          LEON  ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst
# ...         ...         ...  ..         ...          ...             ...
# 5273  KATHERINE      ALSDON   F   6-28-2011   01-07-2016  Senior Manager
# 5274     LOUISE     ALTARAS   F   1-14-2014   01-07-2016         Analyst
# 5275      RENEE      ALVINO   F   1-23-2014   01-07-2016         Analyst
# 5276       TERI   ANASTASIO   F   3-17-2014   01-07-2016         Analyst
# 5277    GREGORY      ABARCA   M   9-18-2014   01-07-2016         Analyst
#
#        AGE  SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  \
# 0     21.0   44570     Finance         24.0               6.0      2.0
# 1      NaN   89207         Web          NaN              13.0      NaN
# 2     21.0   40955     Finance         23.0               7.0      3.0
# 3     22.0   45550          IT         22.0               8.0      3.0
# 4      NaN   43161  Operations         27.0               3.0      NaN
# ...    ...     ...         ...          ...               ...      ...
# 5273  36.0  185977  Management         15.0              15.0      5.0
# 5274  23.0   45758          IT         17.0              13.0      2.0
# 5275  21.0   47315         Web         29.0               1.0      5.0
# 5276  24.0   45172         Web         23.0               7.0      3.0
# 5277  24.0   49176   Marketing         17.0              13.0      2.0
#
#       PAST EXP
# 0            0
# 1            7
# 2            0
# 3            0
# 4            3
# ...        ...
# 5273        10
# 5274         0
# 5275         0
# 5276         1
# 5277         2
#
# [5278 rows x 13 columns]

# %%
### query SQL com SQLAlchemy ORM

# Criar uma sessão
Session = sessionmaker(bind=engine)
session = Session()

query = select(Funcionario)
result = session.execute(query).all() # o mesmo que SELECT * FROM funcionarios;

for row in result: 
    print(row.Funcionario.id, row.Funcionario.first_name, row.Funcionario.age, row.Funcionario.designation)

session.commit()

# Fechar a sessão 
session.close()
# Out:
# 2025-01-16 16:15:03,197 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-16 16:15:03,200 INFO sqlalchemy.engine.Engine SELECT employees.id, employees.first_name, employees.last_name, employees.sex, employees.doj, employees."current_date", employees.designation, employees.age, employees.salary, employees.unit, employees.leaves_used, employees.leaves_remaining, employees.ratings, employees.past_experience
# FROM employees
# 2025-01-16 16:15:03,201 INFO sqlalchemy.engine.Engine [cached since 665.2s ago] ()
# 2025-01-16 16:15:03,203 INFO sqlalchemy.engine.Engine COMMIT
